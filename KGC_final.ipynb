# %%
# !pip install stanza
# !pip install indic-nlp-library
# Out:
# Requirement already satisfied: stanza in c:\users\chakr\anaconda3\lib\site-packages (1.8.2)
# Requirement already satisfied: emoji in c:\users\chakr\anaconda3\lib\site-packages (from stanza) (2.12.1)
# Requirement already satisfied: numpy in c:\users\chakr\anaconda3\lib\site-packages (from stanza) (1.24.4)
# Requirement already satisfied: protobuf>=3.15.0 in c:\users\chakr\anaconda3\lib\site-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in c:\users\chakr\anaconda3\lib\site-packages (from stanza) (2.31.0)
# Requirement already satisfied: networkx in c:\users\chakr\anaconda3\lib\site-packages (from stanza) (3.1)
# Requirement already satisfied: toml in c:\users\chakr\anaconda3\lib\site-packages (from stanza) (0.10.2)
# Requirement already satisfied: torch>=1.3.0 in c:\users\chakr\anaconda3\lib\site-packages (from stanza) (2.3.1)
# Requirement already satisfied: tqdm in c:\users\chakr\anaconda3\lib\site-packages (from stanza) (4.65.0)
# Requirement already satisfied: filelock in c:\users\chakr\anaconda3\lib\site-packages (from torch>=1.3.0->stanza) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\chakr\anaconda3\lib\site-packages (from torch>=1.3.0->stanza) (4.9.0)
# Requirement already satisfied: sympy in c:\users\chakr\anaconda3\lib\site-packages (from torch>=1.3.0->stanza) (1.12)
# Requirement already satisfied: jinja2 in c:\users\chakr\anaconda3\lib\site-packages (from torch>=1.3.0->stanza) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\chakr\anaconda3\lib\site-packages (from torch>=1.3.0->stanza) (2023.10.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\chakr\anaconda3\lib\site-packages (from torch>=1.3.0->stanza) (2021.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chakr\anaconda3\lib\site-packages (from requests->stanza) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chakr\anaconda3\lib\site-packages (from requests->stanza) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chakr\anaconda3\lib\site-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chakr\anaconda3\lib\site-packages (from requests->stanza) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\chakr\anaconda3\lib\site-packages (from tqdm->stanza) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\chakr\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.3.0->stanza) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\chakr\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.3.0->stanza) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chakr\anaconda3\lib\site-packages (from jinja2->torch>=1.3.0->stanza) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\chakr\anaconda3\lib\site-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: indic-nlp-library in c:\users\chakr\anaconda3\lib\site-packages (0.92)
# Requirement already satisfied: sphinx-argparse in c:\users\chakr\anaconda3\lib\site-packages (from indic-nlp-library) (0.4.0)
# Requirement already satisfied: sphinx-rtd-theme in c:\users\chakr\anaconda3\lib\site-packages (from indic-nlp-library) (2.0.0)
# Requirement already satisfied: morfessor in c:\users\chakr\anaconda3\lib\site-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: pandas in c:\users\chakr\anaconda3\lib\site-packages (from indic-nlp-library) (1.5.3)
# Requirement already satisfied: numpy in c:\users\chakr\anaconda3\lib\site-packages (from indic-nlp-library) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\chakr\anaconda3\lib\site-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chakr\anaconda3\lib\site-packages (from pandas->indic-nlp-library) (2023.3.post1)
# Requirement already satisfied: sphinx>=1.2.0 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx-argparse->indic-nlp-library) (5.0.2)
# Requirement already satisfied: docutils<0.21 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx-rtd-theme->indic-nlp-library) (0.18.1)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx-rtd-theme->indic-nlp-library) (4.1)
# Requirement already satisfied: six>=1.5 in c:\users\chakr\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->indic-nlp-library) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.3)
# Requirement already satisfied: Jinja2>=2.3 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.3)
# Requirement already satisfied: Pygments>=2.0 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.15.1)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=1.3 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.11.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.7.12)
# Requirement already satisfied: imagesize in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.31.0)
# Requirement already satisfied: packaging in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (23.1)
# Requirement already satisfied: colorama>=0.3.5 in c:\users\chakr\anaconda3\lib\site-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chakr\anaconda3\lib\site-packages (from Jinja2>=2.3->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chakr\anaconda3\lib\site-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2024.6.2)

# %%
import os
import stanza
from indicnlp.tokenize import indic_tokenize
import re

# %%
stanza.download("te")
telugu_nlp = stanza.Pipeline("te", processors="tokenize,pos,lemma,depparse")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-07-06 05:47:09 INFO: Downloaded file to C:\Users\chakr\stanza_resources\resources.json
# 2024-07-06 05:47:09 INFO: Downloading default packages for language: te (Telugu) ...
# 2024-07-06 05:47:10 INFO: File exists: C:\Users\chakr\stanza_resources\te\default.zip
# 2024-07-06 05:47:12 INFO: Finished downloading models and saved to C:\Users\chakr\stanza_resources
# 2024-07-06 05:47:12 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-07-06 05:47:13 INFO: Downloaded file to C:\Users\chakr\stanza_resources\resources.json
# 2024-07-06 05:47:13 INFO: Loading these models for language: te (Telugu):
# ==========================
# | Processor | Package    |
# --------------------------
# | tokenize  | mtg        |
# | pos       | mtg_charlm |
# | lemma     | identity   |
# | depparse  | mtg_charlm |
# ==========================
#
# 2024-07-06 05:47:13 INFO: Using device: cpu
# 2024-07-06 05:47:13 INFO: Loading: tokenize
# 2024-07-06 05:47:16 INFO: Loading: pos
# 2024-07-06 05:47:16 INFO: Loading: lemma
# 2024-07-06 05:47:16 INFO: Loading: depparse
# 2024-07-06 05:47:16 INFO: Done loading processors!

# %%
'''from google.colab import drive
drive.mount('/content/drive')'''
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')"

# %%
def tokenize_telugu(text):
    return indic_tokenize.trivial_tokenize(text)

# %%
'''import os
import csv

all_triplets = []
telugu_stop_words = set([
    'అందరు', 'అప్పుడు', 'అయితే', 'ఇప్పటికే', 'అందులో', 'అందుకే', 'ఇంకా', 'ఇప్పటికీ', 'కానీ', 'కేవలం', 'గురించి', 'జరిగిన', 'ఇచ్చిన', 'ఎవరూ', 'ఇక్కడ', 'అందువల్ల',
    'అలాగే', 'ఆయన', 'ఎందుకంటే', 'ఎందుకు', 'ఎక్కడ', 'కూడా', 'తో పాటు', 'నుండి', 'తర్వాత', 'తర్వాతే', 'తీసుకుని', 'తన', 'తమ', 'తమకు', 'తనకు', 'లేదా',
    'వీరు', 'వీటిని', 'వారు', 'వీళ్ళు', 'వీరే', 'ఇతర', 'వాళ్ళు', 'అప్పటి', 'మరియు', 'ఇంత', 'తాము', 'అది', 'అంటే', 'అన్నా', 'ఇవ్వడం', 'కాదు', 'వాడు', 'అయినా',
    'అలా', 'మరి', 'కాని', 'ఎప్పుడూ', 'కనుక', 'ఇచ్చి', 'అప్పట్లో', 'అవును', 'అప్పుడప్పుడు', 'ఇది', 'ఉంటే', 'కూడా', 'ఎందుకంటే', 'కాని', 'ఎక్కువ', 'మాత్రం',
    'వంటి', 'ఉన్న', 'ఉంది', 'వచ్చిన', 'కి', 'మీ'
])files = /content/drive/My Drive/Dataset_N190457

def extracting_triplets():
    # Specify the maximum number of files to process
    max_files = 1000
    # Counter to keep track of the number of files processed
    processed_count = 0

    for filename in os.listdir(files):
        if filename.endswith(".txt"):
            file_path = os.path.join(files, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                article_text = file.read()

            # Tokenize Telugu text
            telugu_tokens = tokenize_telugu(article_text)

            # Process Telugu text using Stanza
            doc = telugu_nlp(' '.join(telugu_tokens))
            for word in sent.words:
                    if sc <= 1 and rc <= 0 and (word.deprel == 'nsubj' or word.upos in ['NOUN', 'PROPN']):  # Subject
                        if word.text not in telugu_stop_words:
                            sub += word.text + " "
                            sc += 1
                    elif word.deprel in ['obj', 'dobj', 'iobj', 'pobj', 'obl']:  # Object
                        if word.text not in telugu_stop_words:
                            obj += word.text + " "
                            oc += 1
                    elif word.deprel == 'root' or word.upos in ['AUX']:#ADV', 'ADP']:  # Relation
                        if word.text not in telugu_stop_words:
                            rel += word.text + " "
                            rc += 1

                # Strip trailing spaces and append entities and relations to the all_triplets list
                if sub.strip() and obj.strip() and rel.strip():
                    all_triplets.append([sub.strip(), rel.strip(), obj.strip()])

            processed_count += 1
            if processed_count >= max_files:
                break


    return all_triplets

# Call the function to process the files
triplets = extracting_triplets()
# Define the CSV file path
csv_file_path = '/content/drive/My Drive/triplets190457.csv'

# Write the output to a CSV file
with open(csv_file_path, mode='w', encoding='utf-8', newline='') as csv_file:
    writer = csv.writer(csv_file)
    # Write the header
    writer.writerow(['Subject', 'Relation', 'Object'])
    # Write the triplets
    for triplet in triplets:
        writer.writerow(triplet)

print(f"Triplets have been written to {csv_file_path}")'''
# Out:
# 'import os\nimport csv\n\nall_triplets = []\ntelugu_stop_words = set([\n    \'అందరు\', \'అప్పుడు\', \'అయితే\', \'ఇప్పటికే\', \'అందులో\', \'అందుకే\', \'ఇంకా\', \'ఇప్పటికీ\', \'కానీ\', \'కేవలం\', \'గురించి\', \'జరిగిన\', \'ఇచ్చిన\', \'ఎవరూ\', \'ఇక్కడ\', \'అందువల్ల\',\n    \'అలాగే\', \'ఆయన\', \'ఎందుకంటే\', \'ఎందుకు\', \'ఎక్కడ\', \'కూడా\', \'తో పాటు\', \'నుండి\', \'తర్వాత\', \'తర్వాతే\', \'తీసుకుని\', \'తన\', \'తమ\', \'తమకు\', \'తనకు\', \'లేదా\',\n    \'వీరు\', \'వీటిని\', \'వారు\', \'వీళ్ళు\', \'వీరే\', \'ఇతర\', \'వాళ్ళు\', \'అప్పటి\', \'మరియు\', \'ఇంత\', \'తాము\', \'అది\', \'అంటే\', \'అన్నా\', \'ఇవ్వడం\', \'కాదు\', \'వాడు\', \'అయినా\',\n    \'అలా\', \'మరి\', \'కాని\', \'ఎప్పుడూ\', \'కనుక\', \'ఇచ్చి\', \'అప్పట్లో\', \'అవును\', \'అప్పుడప్పుడు\', \'ఇది\', \'ఉంటే\', \'కూడా\', \'ఎందుకంటే\', \'కాని\', \'ఎక్కువ\', \'మాత్రం\',\n    \'వంటి\', \'ఉన్న\', \'ఉంది\', \'వచ్చిన\', \'కి\', \'మీ\'\n])files = /content/drive/My Drive/Dataset_N190457\n\ndef extracting_triplets():\n    # Specify the maximum number of files to process\n    max_files = 1000\n    # Counter to keep track of the number of files processed\n    processed_count = 0\n\n    for filename in os.listdir(files):\n        if filename.endswith(".txt"):\n            file_path = os.path.join(files, filename)\n            with open(file_path, \'r\', encoding=\'utf-8\') as file:\n                article_text = file.read()\n\n            # Tokenize Telugu text\n            telugu_tokens = tokenize_telugu(article_text)\n\n            # Process Telugu text using Stanza\n            doc = telugu_nlp(\' \'.join(telugu_tokens))\n            for word in sent.words:\n                    if sc <= 1 and rc <= 0 and (word.deprel == \'nsubj\' or word.upos in [\'NOUN\', \'PROPN\']):  # Subject\n                        if word.text not in telugu_stop_words:\n                            sub += word.text + " "\n                            sc += 1\n                    elif word.deprel in [\'obj\', \'dobj\', \'iobj\', \'pobj\', \'obl\']:  # Object\n                        if word.text not in telugu_stop_words:\n                            obj += word.text + " "\n                            oc += 1\n                    elif word.deprel == \'root\' or word.upos in [\'AUX\']:#ADV\', \'ADP\']:  # Relation\n                        if word.text not in telugu_stop_words:\n                            rel += word.text + " "\n                            rc += 1\n\n                # Strip trailing spaces and append entities and relations to the all_triplets list\n                if sub.strip() and obj.strip() and rel.strip():\n                    all_triplets.append([sub.strip(), rel.strip(), obj.strip()])\n\n            processed_count += 1\n            if processed_count >= max_files:\n                break\n\n\n    return all_triplets\n\n# Call the function to process the files\ntriplets = extracting_triplets()\n# Define the CSV file path\ncsv_file_path = \'/content/drive/My Drive/triplets190457.csv\'\n\n# Write the output to a CSV file\nwith open(csv_file_path, mode=\'w\', encoding=\'utf-8\', newline=\'\') as csv_file:\n    writer = csv.writer(csv_file)\n    # Write the header\n    writer.writerow([\'Subject\', \'Relation\', \'Object\'])\n    # Write the triplets\n    for triplet in triplets:\n        writer.writerow(triplet)\n\nprint(f"Triplets have been written to {csv_file_path}")'

# %%
import csv

# Define the CSV file path
file_path =  "C:\\Users\\chakr\\Downloads\\triplets190457.csv"

def read_triplets(file_path):
    triplets = []
    with open(file_path, 'r', encoding='utf-8') as file:
        reader = csv.reader(file)
        next(reader)  # Skip the header row if there is one
        for row in reader:
            if len(row) == 3:
                triplets.append(tuple(row))
    return triplets

triplets = read_triplets(file_path)
print(triplets[:5])  # Print the first 5 triplets to verify
# Out:
# [('గుంటూరు జాతీయ', 'ఆలయం', 'రహదారికి మైదానంలో'), ('ప్రపంచంలో మంగళ', 'కనిపించదు', 'మనకు'), ('శ్రీ భూసమేత', 'పేర్కొంటున్నారు', 'తలమానికంగా'), ('ఏడుకొండలపై కొలువై', 'చేసింది', 'అమరావతి'), ('శ్రీ గ\u200cణ\u200cప\u200cతి', 'జ\u200cరిగింది', 'ఆశిస్సుల\u200cతో ఆల\u200cయ')]

# %%
type(triplets[0])
# Out:
# tuple

# %%
len(triplets)
# Out:
# 15378

# %%
triplets
# Out:
# [('గుంటూరు జాతీయ', 'ఆలయం', 'రహదారికి మైదానంలో'),
#  ('ప్రపంచంలో మంగళ', 'కనిపించదు', 'మనకు'),
#  ('శ్రీ భూసమేత', 'పేర్కొంటున్నారు', 'తలమానికంగా'),
#  ('ఏడుకొండలపై కొలువై', 'చేసింది', 'అమరావతి'),
#  ('శ్రీ గ\u200cణ\u200cప\u200cతి',
#   'జ\u200cరిగింది',
#   'ఆశిస్సుల\u200cతో ఆల\u200cయ'),
#  ('లింగ\u200cమ\u200cనేని పూర్ణ\u200cభాస్క\u200cర్\u200c',
#   'చేప\u200cట్టారు',
#   'ఆశ\u200cయంతో'),
#  ('కలియుగ దేవదేవుని', 'వచ్చింది', 'నిత్యం సంవత్సరంలో 2006లో కార్యకరూపానికి'),
#  ('2006లో గణపతి', 'చుట్టారు', 'అనుమతితో'),
#  ('2012లో శ్రీ', 'జరిగింది', 'చేతుల'),
#  ('మొత్తం ఆలయ', 'జరిగింది', 'పర్యవేక్షణలో'),
#  ('సుబ్రమణ్య ఆచార్యులు', 'విశేషం', 'రాతితోనే'),
#  ('తూర్పుగోదావరి జిల్లా', 'అడుగుల', 'గ్రామానికి'),
#  ('అంగుళాల ఎత్తైన', 'నిర్మించారు', 'ధ్వజస్తంభాన్ని'),
#  ('దేవాలయానికి భాగంలో', 'చేశారు', 'నిమిత్తం వేదికతో'),
#  ('శ్రీవారి పాదాలతోనూ', 'దర్శనమిస్తుంది', 'కూర్మావతారంలోనూ'),
#  ('హన్మకొండలో రెవెన్యూ', 'నివాసముంటోంది', 'కాలనీకి ఇంటిలో'),
#  ('2015 తెల్లవారుఝామున', 'మంటలు', 'నడకకు'),
#  ('రోజు రాత్రి', 'వ్యాపించింది', 'సారికకు కుటుంబీకులకు ఇంటిలో'),
#  ('మృతిపై అనుమానాలున్నాయని', 'నినదించాయి', 'లలిత'),
#  ('సారికది అనుమానాస్పాద', 'తీసుకొన్నారు', 'మృతిగా అదుపులోకి'),
#  ('హుజూరాబాద్ లోని', 'చేరారు', 'టెక్నాలజీలో'),
#  ('ఇంజినీరింగ్ పరిచయమైన', 'వివాహమాడినది', 'యాదగిరిగుట్టలో'),
#  ('మామల సారిక', 'చేసినది', 'స్టేషనులో'),
#  ('అనిల్ వివాహేతర', 'చేసినది', 'సంబంధాన్ని'),
#  ('తమది ప్రేమ', 'నిర్వహించింది', 'అనిల్'),
#  ('రాజయ్య ఇంట్లోనే', 'ప్రస్తావించారు', 'విలేకరుల సమావేశం విషయం'),
#  ('పెద్దల అంగీకారంతోనే', 'వివరించారు', 'మొదట్లో వేధింపులకు'),
#  ('పిల్లల కనీస', 'తెలిపారు', 'అవసరాలకు'),
#  ('వీరిపై కేసులు', 'వాపోయారు', 'పలుకుబడులతో'),
#  ('వరకట్న వేధింపు', 'చేసుకొన్నారు', 'కోర్టులో దరఖాస్తు'),
#  ('నిందితులుగా రాజయ్య', 'లభించింది', 'దంపతులకు బెయిల్'),
#  ('ప్రధాన నిందితుడిగా', 'నిరాకరించింది', 'అనిల్ కు బెయిల్'),
#  ('బెయిల్ రద్దు', 'చేసినది', 'వారికి కేసులో న్యాయం డిమాండ్'),
#  ('వరంగల్ అదనపు', 'చేసింది', 'కోర్టులో అనిల్'),
#  ('000 భరణం', 'చేసినది', '15, కోర్టు'),
#  ('దీనిపై ఆదాయ', 'కొట్టివేసింది', 'జిల్లా కోర్టులో'),
#  ('తండ్రి రాజయ్య', 'రూ', 'అసోసియేట్ ప్రొఫెసర్\u200cగా'),
#  ('కోర్టు తీర్పుకు', 'ఆశ్రయించింది', 'అనిల్ కోర్టును'),
#  ('జీవనభృతి అనిల్', 'హాజరైనది', 'కోర్టుకు'),
#  ('అనిల్ వాదులాట', 'జరిగింది', 'ల'),
#  ('తెల్లవారుఝామున అగ్నిప్రమాదంలో', 'ఆహుతైనది', 'కుమారులతో అగ్నికి'),
#  ('సారిక ఎల్', 'తెలిపారు', 'పీ పడకగదిలోకి లోపలి'),
#  ('ప్రాథమిక ఆధారాల', 'తెలిపారు', 'కోణాలలో'),
#  ('justice can', 'suicide', 'She'),
#  ('" మహిళా', 'చేసినవి', 'హత్యపై'),
#  ('సుబేదారీ పోలీసు', 'విచారించారు', 'అదుపులోకి'),
#  ('ముమ్మాటికీ హత్యేనని', 'అభిప్రాయపపడ్డారు', 'కుటుంబీకులు'),
#  ('సారిక కుమారులకు', 'జరిగాయి', 'వాటికలో'),
#  ('కుటుంబ సభ్యులతో', 'పాల్గొన్నారు', 'సంఘంలో'),
#  ('షాహిన్స్ ఆర్గనైజేషన్', 'చిక్కినది', 'చేతికి'),
#  ('మామలు తనను', 'పేర్కొన్నది', 'పదే'),
#  ('పిల్లలను అలవాటైపోయినదని', 'తెలిపినది', 'తనని'),
#  ('అధికారం చేతులలో', 'తెలిపినది', 'ఏమీ'),
#  ('అనిల్ను తల్లిదండ్రులు', 'తెలిపినది', 'అతనికే వత్తాసు మెయిల్'),
#  ('ప్రేమను అర్థం', 'వాపోయింది', 'తప్పిదాన్ని'),
#  ('గర్భిణినని చూడకుండా', 'పేర్కొన్నది', 'వంటింటికి గదులకు'),
#  ('తాను కలకత్తా', 'తెలిపినది', 'మహానగరాలలో'),
#  ('తొలుత వివాహేతర', 'తెలిపినది', 'దాడికి'),
#  ('పుట్టింటివారు చీరను', 'తెలిపినది', 'సైతం'),
#  ('బాధలకు మాటలకు', 'తెలిపినది', 'మెయిల్'),
#  ('చుట్టుప్రక్కల సారిక', 'తెలిపారు', 'వారిని'),
#  ('అభినవ్ అనిల్', 'తెలిపారు', 'మాధవియేనని'),
#  ('గతంలో అభినవ్', 'వెలువరించాయి', 'సెంటిమెంటుతో ఇంటికి'),
#  ('అనిల్ నిర్లక్ష్యానికి', 'తెలిపినవి', 'సారిక స్నేహితుల సహాయంతో'),
#  ('సారిక సాధారణ', 'తెలిపారు', 'గృహిణిగా'),
#  ('సారిక సాఫ్టువేర్', 'ఆరోపించాయి', 'ఉద్యోగంలో సమయంలో బంగారాన్ని'),
#  ('మామలు అనిల్', 'సమర్పించారు', 'దారుణానికి కోర్టుకు రిపోర్టును'),
#  ('సారికనే బెడ్', 'తెలిపారు', 'లోకి లోపలి'),
#  ('మొత్తం మంది', 'తెలిపారు', 'సాక్షులను అభిప్రాయానికి'),
#  ('కిరోసిన్ పెట్రోలు', 'తెలిపారు', 'అవశేషాలేవీ గదిలో'),
#  ('అనుమానాస్పాద మృతిగా', 'తొలగించారు', 'సెక్షను పోలీసులు'),
#  ('బెయిలు రాజయ్య', 'వేశారు', 'దంపతులు'),
#  ('వేధింపులకు గతంలో', 'తెలిపారు', 'ఇంట్లో ఎన్నికలలో ఇంటికి'),
#  ('అనిల్ అక్రమ', 'తీసుకొనబడింది', 'సంబంధం అదుపులోకి'),
#  ('వరంగల్ జిల్లా', 'నిరాకరించింది', 'కుటుంబీకులకు బెయిళ్ళను'),
#  ('సారికది హత్య', 'కలుపబడలేదని', 'ఆహారంలో'),
#  ('ప్రమాదవశాత్తు సిలిండర్', 'చేసినది', 'లీకేజీ'),
#  ('వర్కూరు కర్నూలు', 'గ్రామము', 'జిల్లా మండలానికి'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కోడుమూరులోను కళాశాల కర్నూలులోనూ'),
#  ('వైద్య కళాశాల', 'ఉన్నాయి', 'కళాశాల కర్నూలులో'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'కర్నూలులో'),
#  ('పారామెడికల్ సిబ్బంది', 'ఉన్నారు', 'ఒకరు'),
#  ('గ్రామంలో ప్రైవేటు', 'సౌకర్యాలున్నాయి', 'వైద్య'),
#  ('గ్రామంలో కుళాయిల', 'జరుగుతోంది', 'సరఫరా'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('కాలువ వాగు', 'లభిస్తుంది', 'గ్రామానికి'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('గ్రామంలో ప్రభుత్వ', 'ఉన్నాయి', 'రెండు'),
#  ('బాలబడి మాధ్యమిక', 'ఉన్నాయి', 'అంకిళ్ళలోనూ'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'నగర్లోనూ'),
#  ('వైద్య కళాశాల', 'ఉన్నాయి', 'నగర్లో'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'నగర్లో'),
#  ('గ్రామంలో కుళాయిల', 'జరుగుతోంది', 'సరఫరా'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('కాలంలో ఆమె', 'పాడింది', 'సినిమాల్లో పాటలు'),
#  ('ఆశా భోస్లే', 'జన్మించింది', 'మహారాష్ట్రకు'),
#  ('బెస్ట్ ఫిమేల్', 'పొందినది', 'పురస్కారాలు'),
#  ('దోనె ఆత్కూరు', 'గ్రామము', 'మండలానికి'),
#  ('గతంలో వీజీటీఎం', 'చేరాయి', 'పరిధిలో'),
#  ('విజయవాడ రూరల్', 'ప్రాంతం', 'మండలం పరిధితో పరిధిలోకి'),
#  ('విజయవాడ అర్బన్', 'ఉన్నది', 'ఏరియా'),
#  ('ఇబ్రహీంపట్నం మండలం', 'జి', 'ఏరియా ఏరియా'),
#  ('దోనె ఆత్కూరు', 'ఉన్నాయి', 'సమీపంలో'),
#  ('ఇంద్రకీలాద్రి మంగళగిరి', 'ఆకర్షణలు', 'గ్రామానికి సమీపంలో'),
#  ('ఖండ్రిక పశ్చిమ', 'గ్రామము', 'మండలానికి'),
#  ('సంచార వైద్య', 'లేరు', 'శాలలో'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'తాడేపల్లిగూడెంలోనూ'),
#  ('సంచార వైద్య', 'లేరు', 'శాలలో'),
#  ('గ్రామంలో కుళాయిల', 'జరుగుతోంది', 'సరఫరా'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('చక్రధర్ చెల్లెలితో', 'మొదలవుతుంది', 'ఇద్దర్ని'),
#  ('శిక్ష విడుదలై', 'వెళుతుంది', 'అతనితో కోటిపల్లి'),
#  ('రఛ్ఛబండ తనను', 'కృష్ణ', 'జైలుకు'),
#  ('వ్యతిరేకంగా సాక్ష్యం', 'పరుస్తుంది', 'అతనికి కథానాయిక'),
#  ('భాగంలో కృష్ణ', 'తెలుసుకుంటుంది', 'నిజం'),
#  ('చరణ్ రాజ్', 'పడతారు', 'కృష్ణని కథానాయికలూ'),
#  ('మర్రిపాలెం విశాఖపట్నం', 'గ్రామం', 'జిల్లా మండలానికి'),
#  ('బాలబడి ప్రాథమిక', 'ఉన్నాయి', 'పెదగరువులోను పెదగరువులోనూ'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల పాడేరులోనూ'),
#  ('సమీప వైద్య', 'ఉన్నాయి', 'పాడేరులోను కళాశాల అనకాపల్లిలోనూ'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'అనకాపల్లిలోను'),
#  ('సంచార వైద్య', 'లేరు', 'శాలలో'),
#  ('మురుగునీటిని శుద్ధి', 'పంపిస్తున్నారు', 'ప్లాంట్\u200cలోకి'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'గంటల కోసం'),
#  ('నల్లబిల్లి కాశీపతిరాజపురం', 'గ్రామము', 'మండలానికి'),
#  ('తెలుగు జానపద', 'ఉన్నది', 'వారికి'),
#  ('వినోదాన్ని విజ్ఞానాన్ని', 'కళలే', 'ప్రజలకు'),
#  ('ప్రాచీన సమాజంలో', 'లేదు', 'వినోదం'),
#  ('పరివర్థితులైన శిష్టుల', 'అయ్యేవి', 'ప్రజల కొలువులకు'),
#  ('సామాన్యానికి జానపదులకు', 'కళలే', 'జీవితాన్నే'),
#  ('పురాణాలన్నింటినీ దృశ్య', 'ప్రజాకళలే', 'మాధ్యమంలో'),
#  ('తెలుగు జానపద', 'అవుతాయి', 'చరిత్రలోనికి మనకు'),
#  ('పరివర్థిత నాటకానికి', 'మూలాలు', 'నాటకానికి'),
#  ('సంవత్సరాలనాటిదిగా భరతుని', 'ఉన్నాయి', 'నాట్య'),
#  ('ప్రాచీన కాలంనుండి', 'లేవు', 'కాలంనుండి'),
#  ('శాతవాహనులు తెలుగు', 'చెబుతున్నారు', 'రాజులు'),
#  ('నాటిదైన సప్తశతిలో', 'చూపారు', 'సంగీత వాద్యాలకు విద్వాంసులు'),
#  ('ఆధారాలు అవి', 'కష్టం', 'భాషలో'),
#  ('వ శతాబ్ది', 'చెప్పవచ్చు', 'కాలంనాటికే ఆధారాలతో'),
#  ('ఆధారాలు లేనంత', 'వీలులేదు', 'శతాబ్దాలలో'),
#  ('ఆరవ శతాబ్ది', 'చూపుతున్నారు', 'కాలంనాటికే'),
#  ('వివరమైన ఆధారాలు', 'లభించలేదు', 'వాటిని శాసనాలలో'),
#  ('క్రీస్తుశకం ప్రాంతం', 'రచించాడు', 'సాహిత్యంలో'),
#  ('జానపద గేయాలలో', 'ఉంటాయి', 'రూపాలు'),
#  ('ప్రచారం అవసరం', 'రచించారు', 'సాహిత్యానికి'),
#  ('జానపద జీవితాన్ని', 'వర్ణించాడు', 'జానపదులైన'),
#  ('అవసరం', 'లేదు', 'వాటిని'),
#  ('రోకళ్ళ పాటలను', 'చెప్పాడు', 'వాటిని ఘట్టాల్ని'),
#  ('రాయలసీమలో మెరవణిని', 'ప్రస్తావించాడు', 'ఆనాడే'),
#  ('చిందువారి ప్రసక్తి', 'కావచ్చు', 'యక్షగానం'),
#  ('వెడయాట కోడంగియాట', 'చెప్పాడు', 'వాటిని'),
#  ('యుగాలలోని కావ్యాలలో', 'కనిపిస్తుంది', 'మనకు'),
#  ('కిషన్ రావుగారు', 'చేశారు', 'పరిశోధన'),
#  ('మంది పండితులు', 'అందిచారు', 'పరిశోధనలలో కళలకు తావుల్లో'),
#  ('ఆధారాలు కాలం', 'లభించవచ్చు', 'పరిశోధనలలో'),
#  ('తెలుగు జానపద', 'కనిపిస్తాయి', 'వృత్తిగా'),
#  ('భారత దేశంలోని', 'జానపదకళలే', 'రాష్ట్రాలలో ప్రాంతాలలో'),
#  ('ఒగ్గుకథ పంబకథ', 'కళారూపాలే', 'వృత్తిగా'),
#  ('ఉదాహరణలు', 'చూడవచ్చు', 'కొన్ని'),
#  ('ఎవరు విషయాన్ని', 'చేయవచ్చు', 'ఎవరికి విభజన'),
#  ('అనియతాశ్రయ కళారూపాలు', 'అర్థం', 'వారి'),
#  ('ఉదాహరణకి పాముల', 'ప్రదర్శిస్తాడు', 'గ్రామంలో ఆగ్రామంలో అందరికీ'),
#  ('హరిదాసు గ్రామానికి', 'తీసుకుంటాడు', 'ఇండ్లకు'),
#  ('బహురూపుల పగటివేషగాళ్ళు', 'ప్రదర్శిస్తారు', 'కళను'),
#  ('తోలు బొమ్మలాట', 'ప్రదర్శించబడతాయి', 'అందరికోసం'),
#  ('మరికొన్నికళారూపాలనూ', 'చెప్పవచ్చు', 'వాటిని'),
#  ('కళలను కళాకారులు', 'అనవచ్చు', 'ఊరి'),
#  ('కులంవారికే జానపద', 'ఉన్నాయి', 'కాకుండా'),
#  ('రుంజకథా గాయకుడు', 'లేదు', 'గ్రామానికి మొత్తానికి'),
#  ('ప్రత్యేకించి దాతలైన', 'ప్రదర్శిస్తాడు', 'అతనికి'),
#  ('కళారూపంలో కథ', 'మాత్రమే', 'కులానికి'),
#  ('కళా ప్రదర్శన', 'ఉంటుంది', 'విశ్వబ్రాహ్మణులకు'),
#  ('కళా ప్రదర్శన', 'ఉంటుంది', 'రెడ్లకు పరిమితమై'),
#  ('అతను కథ', 'మాత్రమే', 'వారికి'),
#  ('ఉద్దేశంలో అతను', 'మాత్రమే', 'కథ రెడ్లకు'),
#  ('కూనపులి సాలె', 'చెప్తారు', 'కథ'),
#  ('చిందువారు గోసంగి', 'ప్రదర్శిస్తారు', 'వేషాన్ని మాదిగవారికి'),
#  ('కులాలవారికి ఆశ్రితులు', 'చెప్తున్నారు', 'కథను'),
#  ('ప్రదర్శిచే జానపద', 'అనవచ్చు', 'కళలను కళారూపాలు'),
#  ('తెలుగు జానపద', 'కుదరదు', 'కళలలో వైవిధ్యాన్ని'),
#  ('కళాకారుడు పాత్రలు', 'ప్రదర్శిస్తాడు', 'నటించి కథను ప్రేక్షకులకు'),
#  ('పిట్టల దొర', 'ఉండదు', 'ప్రదర్శనలో'),
#  ('కళాకారులు కళారూపాలు', 'ఉన్నాయి', 'దీని మనకు'),
#  ('కళాకారులు ఒకడు', 'కళారూపాలు', 'ఉండి ఇద్దరు కాలానికి'),
#  ('తెలుగులో ఉన్నన్ని', 'కష్టం', 'దేశంలోని'),
#  ('కళాకారులు కథను', 'ఉంటుంది', 'ఉండడంలో'),
#  ('కథను సందర్భంలోనూ', 'జరుగుతుంది', 'పాటలో'),
#  ('కథాగానాన్ని కథకుడే', 'జరుగుతుంది', 'ముగ్గురి'),
#  ('కళాకారులు కథను', 'చిత్రిస్తారు', 'గుడ్డమీద'),
#  ('చుట్టను గుంజల', 'ప్రత్యేకత', 'కర్రతో'),
#  ('వేలాడ పటానికి', 'ప్రదర్శిస్తారు', 'సహాయంతో'),
#  ('కథకుడు వంతలు', 'ప్రత్యేకత', 'కళాప్రదర్శనలో'),
#  ('కథలోని పాత్రలను', 'చెబుతారు', 'బొమ్మలుగాచేసి వాటిని కథను'),
#  ('కళాప్రదర్శన పరిణామ', 'వీలుంది', 'బొమ్మలాటకు'),
#  ('తోలుబొమ్మలాటను ప్రక్రియా', 'చెప్పడానికివీలుంది', 'పరిణామం'),
#  ('వ్యక్తి పాత్రను', 'వీలుంది', 'కథను'),
#  ('తెలుగులో వీధినాటక', 'ఉన్నాయి', 'ప్రాంతాలలో'),
#  ('తెలంగాణా సర్కారు', 'ఇలాంటివి', 'ప్రాంతాలలో'),
#  ('రంగస్థలం', 'లేదు', 'వీటికి'),
#  ('వీధినాటక రీతి', 'ఉన్నాయి', 'పూర్తినాటకానికి తెలుగులో యక్షగాన'),
#  ('పాత్రలకు పాత్రధారులు', 'యక్షగానం', 'రంగస్థలాన్ని'),
#  ('యక్షగాన ప్రదర్శలనకు', 'ప్రదర్శించవచ్చు', 'రంగస్థలం'),
#  ('చిందు యక్షగానాన్ని', 'లభిస్తున్నాయి', 'తెలుగులో యక్షగానాలలోనికి'),
#  ('తెలంగాణా యక్షగాన', 'ఉంటుంది', 'యక్షగానానికి'),
#  ('కర్ణాటకలో ఈనాడు', 'కనిపిస్తుంది', 'ప్రచారంలో యక్షగానంనుండి'),
#  ('కూచిపూడి యక్షగానం', 'చెందుతుంది', 'కాలంలో కాలంనుండి'),
#  ('ప్రాచీన కాలంనుండి', 'తోలుబొమ్మలాటలు', 'కళలో'),
#  ('దీన్ని ప్రాచీన', 'చెప్పవచ్చు', 'కాలపు సినిమాగా'),
#  ('మానవ పాత్రలతో', 'పరిణామం', 'బొమ్మలతో'),
#  ('జానపద కళా', 'మచ్చులు', 'మనిషి'),
#  ('తెలుగు కళాప్రదర్శన', 'ఉన్నాయి', 'వారికి'),
#  ('తోలు బొమ్మలాట', 'యక్షగానం', 'సంగీత'),
#  ('పాత్రలు మనుషులకు', 'ఉంటాయి', 'బొమ్మలు'),
#  ('మాతృభాష మరాఠీ', 'కనిపించదు', 'ప్రదర్శనలో తెలుగులో'),
#  ('తెలుగు మాతృభాషగా', 'ఉంటుంది', 'వారి'),
#  ('బుడిగజంగాలు', 'అనిఅంటారు', 'వీరిని'),
#  ('శతాబ్ది నాటికే', 'లభించాయి', 'ఉందని'),
#  ('అవసరమైన చెక్క', 'ఉన్నాయి', 'వీరికి బొమ్మలు'),
#  ('ప్రదర్శన కళలలో', 'చూశాము', 'పాత్రధారులతో సంప్రదాయంలో'),
#  ('ఉత్తరాంధ్రప్రాంతంలోప్రవర్తితమయ్యే తప్పెటగుళ్ళు', 'ప్రధానమైంది', 'సంగీత'),
#  ('ప్రదర్శనకు తావు', 'ఉంటుంది', 'వాద్యానికి సంగీతానికి'),
#  ('నృత్య సంప్రదాయాలు', 'ఉన్నాయి', 'మనకు'),
#  ('భూమి సూర్యుని', 'అంటారు', 'భ్రమణ స్థానానికి'),
#  ('ఉదాహరణకు సూర్యుని', 'అనవచ్చును', 'చుట్టూ'),
#  ('గ్రిగేరియన్ కేలెండర్', 'అనుసరిస్తాయి', 'year'),
#  ('విధానంలో సంవత్సరం', 'నిరూపించారు', 'నగరంలో జోన్'),
#  ('లీప్ సంవత్సరం', 'సరిచేస్తుంటారు', 'వంటివాటితోలో'),
#  ('పృథ్వీరాజ్ కపూర్', 'కళాకారుడు', 'పరిశ్రమలో'),
#  ('పృథ్వీరాజ్ 1906',
#   'జన్మించాడు',
#   'పాకిస్తాన్ లోని లయాల్\u200cపూర్ కుటుంబంలో'),
#  ('పృథ్వీరాజ్ పంజాబీతో', 'మాట్లాడేవాడు', 'భాషలు'),
#  ('ఖమ్మం జిల్లాలో', 'కృషిచేశాడు', 'వికాసానికి'),
#  ('ఖమ్మం జిల్లా', 'జన్మించాడు', 'దుమ్ముగూడెంలో'),
#  ('సంపన్న కుటంబంలో', 'కలిగింది', 'నాటకాలపై'),
#  ('1914లోనే దుమ్మగూడెంలో', 'జరిగాయి', 'ప్రోద్బలంతో'),
#  ('సుజన వినోదిని', 'స్థాపించాడు', 'సమాజాన్ని 1944లో కళాసమితిని'),
#  ('మరళీ మనోహర', 'వహించాడు', 'ఆహ్వానంపై సమాజం నాటకాలను దర్శకత్వం'),
#  ('వేదములు పురాణములు', 'చాటుచున్నవి', 'మాహిమను'),
#  ('భస్మ స్నానము', 'సమానము', 'సర్వతీర్ధాలు'),
#  ('విభూది నొసట', 'తారుమారగును', 'ధరించి'),
#  ('హోమగుండంలో మోదుగ', 'ఉపయోగిస్తారు', 'ఆవునెయ్యి'),
#  ('కుడిచేతి మధ్యమ', 'తీసుకోవాలి', 'వేళ్ళ విభూతిని చేతిలోకి'),
#  ('నుదుటిపై ఎడమవైపు', 'తీర్చిదిద్దాలి', 'కుడివైపుకు'),
#  ('అంగుష్టముతో విభూతి', 'అంటారు', 'కుడివైపు ఎడమవైపుకు మూడు'),
#  ('విభూతి నుదిటిపై', 'ధరించకూడదు', 'క్రిందికిగాని'),
#  ('విభూతిధారణ దేవతాపూజ', 'సిద్ధించును', 'శుభకార్యముల్లో'),
#  ('విభూతి భస్మం', 'కూడదు', 'తీర్ధప్రసాదములు'),
#  ('ఆకాశ వర్ణము', 'మేలు', 'హోమభస్మాలు'),
#  ('గమనిక హోమభస్మాన్ని', 'ఉంచకూడదు', 'పరిస్థితుల్లోనూ నేలపై'),
#  ('ఒంటి నిండా', 'అంటారు', 'దానిని'),
#  ('బూడిద', 'అంటాం', 'దానిని'),
#  ('ఉదజని వాయువును', 'నీరు', 'ఆమ్లజని'),
#  ('కాకానూరు కర్నూలు', 'గ్రామము', 'జిల్లా ఆత్మకూరు'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల కర్నూలు'),
#  ('డిగ్రీ డాక్టరు', 'ఉన్నారు', 'ఒకరు'),
#  ('గ్రామంలో కుళాయిల', 'అవుతోంది', 'నీరు'),
#  ('కాలువ వాగు', 'లభిస్తుంది', 'గ్రామానికి'),
#  ('మురుగు నీటిని', 'తున్నారు', 'జలవనరుల్లోకి'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('కాకానూరులో వ్యవసాయానికి', 'జరుగుతోంది', 'వనరుల'),
#  ('గొమ్ము అయ్యవారిగూడెం', 'గ్రామము', 'గోదావరి మండలానికి'),
#  ('బాలబడి ప్రాథమికోన్నత', 'ఉన్నాయి', 'కూనవరంలో'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల భద్రాచలంలోనూ'),
#  ('వైద్య కళాశాల', 'ఉన్నాయి', 'కళాశాల భద్రాచలంలోనూ'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'పాల్వంచలోను ఖమ్మం'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('మురుగునీటిని శుద్ధి', 'పంపిస్తున్నారు', 'ప్లాంట్\u200cలోకి'),
#  ('గ్రామం పారిశుధ్య', 'రావట్లేదు', 'పథకం కిందకు'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('జిల్లా రహదారి', 'పోతోంది', 'గ్రామం'),
#  ('గొమ్ము అయ్యవారిగూడెంలో', 'అవుతున్నాయి', 'వస్తువులు'),
#  ('కమతంపల్లె అనంతపురం', 'గ్రామము', 'జిల్లా మండలానికి'),
#  ('బాలబడి ప్రాథమికోన్నత', 'ఉన్నాయి', 'కదిరిలో'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల అనంతపురంలోనూ'),
#  ('సమీప వైద్య', 'ఉన్నాయి', 'కళాశాల కదిరిలోనూ'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'గాండ్లపెంటలోను కదిరిలోనూ'),
#  ('గ్రామంలో కుళాయిల', 'అవుతోంది', 'నీరు'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('జిల్లా రహదారి', 'పోతోంది', 'గ్రామం'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('కమతంపల్లెలో వ్యవసాయానికి', 'జరుగుతోంది', 'వనరుల'),
#  ('వేరుశనగ వరి', 'చూడండి', 'వివరాలకు'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల కళాశాల హిందూపురంలో'),
#  ('వైద్య కళాశాల', 'ఉన్నాయి', 'అనంతపురంలోను కళాశాల హిందూపురంలోనూ'),
#  ('ఎమ్బీబీయెస్ డాక్టరు', 'ఉన్నారు', 'నలుగురు'),
#  ('గ్రామంలో కుళాయిల', 'అవుతోంది', 'నీరు'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('ప్రభుత్వ ప్రాథమిక', 'ఉన్నాయి', 'ఒకటి'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల ఖమ్మంలోనూ'),
#  ('వైద్య కళాశాల', 'ఉన్నాయి', 'కళాశాల ఖమ్మంలో'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'ఖమ్మం'),
#  ('సంచార వైద్య', 'లేరు', 'శాలలో'),
#  ('గ్రామంలో ప్రైవేటు', 'సౌకర్యాలున్నాయి', 'వైద్య'),
#  ('డిగ్రీ డాక్టర్లు', 'ఉన్నారు', 'ఇద్దరు'),
#  ('గ్రామంలో కుళాయిల', 'జరుగుతోంది', 'సరఫరా'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('జిల్లా రహదారి', 'పోతోంది', 'గ్రామం'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('ములగుంటపాడు ప్రకాశం', 'గ్రామము', 'జిల్లా మండలానికి'),
#  ('పంచాయతీ రాష్ట్రంలో', 'ఎంపికైనది', 'పంచాయతీగా'),
#  ('జాతీయ పంచాయతీరాజ్', '2017', 'వేడ్కలలో'),
#  ('24న విజయవాడలో', 'అందజేసెదరు', 'చేతులమీదుగా'),
#  ('పండు రామాఫలం', 'దొరుకుతుంది', 'రకాల్లోనూ'),
#  ('మార్కెట్లో అవి', 'చేస్తుంది', 'కనిపిస్తాయా'),
#  ('దక్షిణ అమెరికా', 'తీసుకొచ్చారట', 'దేశాల్లో మనదేశానికి శతాబ్దంలో'),
#  ('సీతాఫలం అమృతఫలాన్ని', 'పిలుస్తారు', 'సీతాఫలాన్నే'),
#  ('దక్షిణ అమెరికా', 'పండుతుంది', 'మనదేశంలోనూ'),
#  ('భాగాల్నీ వ్యాధుల', 'వాడతారట', 'నివారణలో'),
#  ('బెరడుని డికాక్షన్\u200c', 'తగ్గిస్తుందట', 'డయేరియాని'),
#  ('ఆకుల కషాయం', 'నివారిస్తుందట', 'జలుబుని'),
#  ('గుజ్జు నోటిలోని', 'పెంచుతుంది', 'జీర్ణరసాలను'),
#  ('పండు గుజ్జును', 'తాగించాలి', '* పిల్లలకు'),
#  ('* మలబద్ధకంతో', 'పనిచేస్తుంది', 'బాధపడేవారికి దివ్యౌషధంలా'),
#  ('డైటింగ్\u200c నియమాలు', 'స్వీకరించవచ్చు', 'సైతం ఫలాన్ని'),
#  ('పండులోని సల్ఫర్\u200c', 'తగ్గిస్తుంది', 'చర్మవ్యాధుల్నీ'),
#  ('సీతాఫలం గుజ్జు', 'వేస్తుంది', 'వెలుపలికి'),
#  ('ఆకుల్లోని హైడ్రోస్తెనిక్\u200c', 'తగ్గిస్తుంది', 'సమస్యల్ని'),
#  ('ఆకుల్ని బోరిక్\u200c', 'ఉండదు', 'మూలల్లో'),
#  ('సీతాఫలం బెరడును', 'ఇస్తుంటారు', 'విరేచనాలతో'),
#  ('* సీతాఫలం', 'ఉండదు', 'గింజల్ని తలకు'),
#  ('గర్భిణులు పండును', 'తినాలి', 'సాధ్యమైంత'),
#  ('పొరబాటున గింజలు', 'ప్రమాదముంది', 'లోపలికి'),
#  ('అరచెంచా వాము', 'లభిస్తుంది', 'ఉప్పు'),
#  ('మధుమేహ వ్యాధి', 'తీసుకోవాలి', 'సలహాతో'),
#  ('* జలుబు', 'మంచిది', 'సమస్యలో'),
#  ('నోటిలో జీర్ణరసాలను', 'పండుకు', 'ఊరేలా'),
#  ('మెగ్నీషియం శరీరంలోని', 'విశ్రాంతినిస్తుంది', 'కండరాలకు'),
#  ('కాల్షియం ఎముకల', 'పెంచుతుంది', 'పటుత్వాన్ని'),
#  ('ఉబ్బసం రోగులు', 'తినాలి', 'సలహా'),
#  ('సీతాఫలాలను ఖాళీ', 'తినాలి', 'కడుపుతో'),
#  ('బాలబడి మాధ్యమిక', 'ఉన్నాయి', 'గుమ్మడిదలలో'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'నర్సాపూర్లోనూ'),
#  ('సమీప మేనేజిమెంటు', 'ఉన్నాయి', 'కళాశాల కళాశాల సంగారెడ్డిలోనూ'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'హైదరాబాదు'),
#  ('గ్రామంలో కుళాయిల', 'జరుగుతోంది', 'సరఫరా'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల అనంతపురంలోనూ'),
#  ('సమీప వైద్య', 'ఉన్నాయి', 'కళాశాల కదిరిలోనూ'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'నల్లమాడలోను అనంతపురంలోనూ'),
#  ('గ్రామంలో కుళాయిల', 'జరుగుతోంది', 'సరఫరా'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('జిల్లా రహదారి', 'పోతోంది', 'గ్రామం'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('పినపాలెం విశాఖపట్నం', 'గ్రామము', 'జిల్లా మండలానికి'),
#  ('బాలబడి మాధ్యమిక', 'ఉన్నాయి', 'గడుతూరులోనూ'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల పాడేరులోనూ'),
#  ('సమీప వైద్య', 'ఉన్నాయి', 'కళాశాల పాడేరులోనూ'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'అనకాపల్లిలోను'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('మురుగునీటిని శుద్ధి', 'పంపిస్తున్నారు', 'ప్లాంట్\u200cలోకి'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('బాలబడి ప్రాథమిక', 'ఉన్నాయి', 'తెంబూరులోనూ'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల టెక్కలిలోనూ'),
#  ('వైద్య కళాశాల', 'ఉన్నాయి', 'టెక్కలిలోనూ'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('జిల్లా రహదారి', 'పోతోంది', 'గ్రామం'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('మజ్జిగోపాలపురంలో వ్యవసాయానికి', 'జరుగుతోంది', 'వనరుల'),
#  ('జంధ్యాల సుబ్రహ్మణ్యశాస్త్రి', 'దర్శకుడు', 'సినిమా'),
#  ('ప్రత్యేకించి హాస్యకథా', 'చెయ్యి', 'చిత్రాలు'),
#  ('పశ్చిమ గోదావరి', 'జన్మించాడు', 'జిల్లా నరసాపురంలో'),
#  ('1974లో జంధ్యాల', 'చేసాడు', 'ప్రవేశం'),
#  ('శంకరాభరణం సాగరసంగమం', 'రాశాడు', 'సినిమాలకు'),
#  ('ముద్దమందారం దర్శకుడిగా', 'సృజించాడు', 'సినిమాతో చిత్రాన్ని'),
#  ('హైదరాబాదులో గుండె', 'మరణించాడు', 'పోటుతో'),
#  ('1976 దేవుడు', 'మొదలుపెట్టాడు', 'రచయితగా సినిమా'),
#  ('సుమారు సినిమాలకు', 'తెచ్చుకున్నాడు', 'రచయితగా రచయితగా'),
#  ('కాలంలో దర్శకుడిగా', 'రూపొందించాడు', 'హాస్యచిత్రాలను'),
#  ('ఆరోగ్యకరమైన హాస్యానికి', 'పేరుగాంచాడు', 'జంధ్యాల'),
#  ('1992 ఆపద్బాంధవుడు', 'చేసాడు', 'రంగానికి'),
#  (': మట్టి', 'సంభాషణ', 'పూసుకొని'),
#  ('రాజా ప్రియురాలు', 'చూపమంటాడు', 'కోపంతో'),
#  ('" రాజుగారి', 'చూసి', 'క్లాసులో సత్యనారాయణని'),
#  ('2002లో సత్యం', 'ప్రవేశించాడు', 'చిత్రం దర్శకుడిగా సినిమారంగంలోకి'),
#  ('మలయాళంలో సినిమా', 'చేస్తున్నాడు', 'కెరీర్ సినిమాలు'),
#  ('సూర్యకిరణ్ దర్శకత్వంలో', 'నటించింది', 'చిత్రాలలో'),
#  ('రావులమ్మపాలెం విశాఖపట్నం', 'గ్రామం', 'జిల్లా మండలానికి'),
#  ('హైదరాబాదు విశ్వవిద్యాలయము', 'యేర్పరచబడింది', 'విశ్వవిద్యాలయముగా'),
#  ('హైదరాబాదు కేంద్రీయ', 'పేరుపొందిన', 'విశ్వవిద్యాలయంగా'),
#  ('విశ్వవిద్యాలయమును ఇటీవల', 'చేశారు', 'హైదరాబాదు విశ్వవిద్యాలయముగా'),
#  ('విశ్వవిద్యాలయము విద్యకు', 'ఎదిగినది', 'భారతదేశములో'),
#  ('హైదరాబాదు విశ్వవిద్యాలయం', 'ఒకటి', 'దేశంలోనే'),
#  ('2012 సంవత్సరంలో', 'నిలబడింది', 'ముందంజలో'),
#  ('ఉత్తమ వర్సిటీతోపాటు', 'చేస్తారు', 'పరిశోధన ఆవిష్కరణలకు'),
#  ('రాష్ట్రపతి సందర్శకుని', 'తెలిపింది', 'వర్సిటీలకు'),
#  ('విద్యార్థుల అధ్యాపకుల', 'వచ్చింది', 'అప్పటినుంచి'),
#  ('2012 నాటికి', 'విస్తరించింది', 'అధ్యాపకులలో'),
#  ('తెలుగు భాష', 'శాఖ', 'ఔన్నత్యాన్ని తనవంతు సహకారాన్ని'),
#  ('శాఖ స్నాతకోత్తర', 'ఎం', 'విద్య'),
#  ('112 పద్యాలతో', 'ముద్రించారు', 'నగాధిపతిశతకం'),
#  ('1930 వర్ణరత్నాకరం', 'ప్రచురించబోతున్నారు', 'వ్యాఖ్యానంతో'),
#  ('మైసూరులోని కేంద్ర', 'నివేదించింది', 'సంస్థలో ప్రణాళిక'),
#  ('యూనివర్సిటీ అఫ్', 'జరిగింది', 'హైదరాబాద్'),
#  ('సంస్థ రంగస్థల', 'భావిస్తోంది', 'శాఖకి ప్రజలందరికీ'),
#  ('సమాచారాన్ని విజ్ఞాన్నాన్ని', 'ప్రయత్నిస్తోంది', 'అందుబాటులో'),
#  ('సమకాలీన తెలుగు', 'సంకల్పించింది', 'నాటకరంగం సమస్యలకు నాటకరంగ పాత్రని'),
#  ('థియేటర్ ఔట్రీచ్', 'ఉన్నాయి', 'యూనిట్'),
#  ('అనునిత్యం నాటక', 'చేయాలి', 'శిబిరాలతో'),
#  ('తెలుగు నాటకరంగంలో', 'పనిచేయాలి', 'సంస్థలతో పరిషత్తులతో'),
#  ('శాఖకున్న వనరులను', 'అందించాలి', 'వారికి'),
#  ('ప్రత్యేకమైన శిక్షణ', 'ఏర్పరచాలి', 'శిబిరాలను'),
#  ('శాఖతో పరిషత్తులకు', 'అందించాలి', 'పరిపుష్టిని'),
#  ('పరిషత్తు ప్రేక్షకుల', 'పెంచగలగాలి', 'పద్ధతుల'),
#  ('మోడల్ పరిషత్తు', 'రూపొందించాలి', 'వాటిని'),
#  ('రాష్ట్రంలోని ఔత్సాహిక', 'ఏర్పాటుచేయాలి', 'నాటక వారితో'),
#  ('గౌరవప్రథమైన ఉపకార', 'ఇప్పించాలి', 'వారందరికి శిక్షణ'),
#  ('నాటక కళ', 'అందించాలి', 'విద్యార్థులకు'),
#  ('రాష్ట్ర వ్యాప్తంగా', 'నిర్వహించాలి', 'స్కూళ్ళలో కాలేజీల్లో ప్రదర్శనలతో'),
#  ('శిక్షణ శిబిరాలకు', 'ఇవ్వాలి', 'ప్రాంతాలలో తర్ఫీదు'),
#  ('ఉన్నతః విద్యలో', 'తయారుచేయాలి', 'ఉపాధికోసం విద్యర్థులందరినీ'),
#  ('దర్శకత్వంలో రాష్ట్రవాప్తంగా', 'చూడాలి', 'కొన్నిస్కూళ్ళలోనూ సంస్థల్లోనూ'),
#  ('తెలుగు నాటకరంగానికీ', 'పూరించాలి', 'నాటకరంగాలకీ అగాధాన్ని'),
#  ('గ్రంథాలయం మొదల', 'ఏర్పడినది', 'శాఖలలో విశ్వవిద్యాలయమునకు'),
#  ('పూర్వ ప్రధానమంత్రి', 'చేసారు', 'గ్రంథాలయానికి'),
#  ('ఉన్నత విద్యా', 'ముఖ్యొద్దేశము', 'బోధన'),
#  ('అందుకు తగినట్లుగా', 'అనుసంధానిపబడిఉన్నది', 'విభాగములతో'),
#  ('గ్రంథాలయఆన్ లైన్', 'అందుబాటులోనున్నది', 'నలుమూలలకు'),
#  ('గ్రంథాలయం కొనుగోలు', 'ప్రచురణలు', 'అదే'),
#  ('VIRTUA అంతర్జాతీయ', 'జరిగింది', 'సహాయముతో'),
#  ('వ్యాసము సామాజిక', 'ఉంటుంది', 'ఏదో విషయాన్ని'),
#  ('1711 12', 'పేరుపెట్టాడు', 'ఆంగ్ల పత్రికలో వ్యాసాలతో'),
#  ('సాక్షి వ్యాసాల', 'ప్రారంభమైంది', '1913లో'),
#  ('పానుగంటి లక్ష్మీనరసింహారావు', 'ప్రచురితమయ్యాయి', 'తణుకు'),
#  ('పానుగంటి సాహిత్యంపై', 'చెప్పాడు', 'వ్యాసాలున్నాయని'),
#  ('పత్రికకు సాక్షి', 'చేరింది', 'పునరుద్ధరణకు సందర్భాలలో'),
#  ('మొట్టమొదట పిఠాపురం', 'ముద్రింపించాడు', 'రాజా'),
#  ('2006లో విజయవాడ', 'ముద్రించారు', 'సంపుటిగా'),
#  ('ఊహాజనితమైన సంఘం', 'సంఘం', 'దురాచారాలను'),
#  ('వ్యాసాలన్నీ సాక్షి', 'తెలియుచేయబడుతాయి', 'సమావేశాలలో'),
#  ('సందర్భములలో కాలాచర్యుడో', 'తెలుస్తాయి', 'వాణీదాసుడో ఎక్కడీకో'),
#  ('వానియందు జనుల', 'ప్రయత్నింతుము', 'కసహ్యము'),
#  ('లేశమును', 'బనిలేదు', 'మాకు వారితో'),
#  ('విషయములను నారోగ్య', 'గూర్చియు', 'ఇంతియేగాక విషయములను'),
#  ('మేము ప్రతిరాత్రియు', 'జేరుదుము', 'నొకచోఁ'),
#  ('ఇప్పటి మాకు', 'జేరుదుము', 'యింటిలోఁ'),
#  ('సాక్షి స్థానము', 'కెదురుగ', 'తపాలకచేరి'),
#  ('బాలనాగమ్మ సభ్యురాలిగా', 'సభ్యురాలే', 'ఆమెను నామమాత్రపు'),
#  ('మహిళలంతా ఓచోట', 'రెచ్చిపోయాడు', 'ఉంటుందో'),
#  ('తోలుబొమ్మలాటను వాణీదాసునికి', 'ఆసక్తి', 'ప్రేక్షకులను'),
#  ('- ముగ్గురో', 'నాడించుచున్నారు', 'నల్వురో'),
#  ('జనుల ముఖభేదముల', 'గుర్తెఱుగుట', 'బరిశీలించుట'),
#  ('పందిటిక్రింద నిర్జీవపు', 'వాడ', 'దోలుబొమ్మలను'),
#  ('బయటనాడుచున్న ప్రాణమున్న', 'బోయితిని', 'తోలుబొమ్మలయాట'),
#  ('తెలుగువాడు తెలుగు', 'అంటాడు', 'శ్రోతలతో ఆంగ్లంలో ఉద్వేగభరితుడై'),
#  ('మ్యావుమని పిల్లి', 'యెచ్చటైననుండునా', '-'),
#  ('రాగి ఆక్సైడులలో', 'ముఖ్యమైనది', 'ఆక్సైడ్'),
#  ('రంగులలో కాపర్', 'ఉపయోగిస్తారు', 'ఆక్సైడును'),
#  ('కాపర్ ఆక్సైడు', 'పదార్థం', 'అమ్మోనియా'),
#  ('పరివర్తన', 'పొందును', '+'),
#  ('కాపర్ ఆక్సైడు', 'చెయ్యును', 'ఆమ్లంతో'),
#  ('కాపర్ ఆక్సైడ్', 'కలిగిఉన్నది', 'అణువు'),
#  ('4.2696 Å', 'చెయ్యవచ్చును', 'పలుపద్ధతులలో'),
#  ('రాగి లోహాన్ని', 'చెయ్యవచ్చును', 'ఆక్సైడును'),
#  ('పారిశ్రామికంగా కాపర్', 'దురు', 'ద్రావాణాలను సల్ఫర్\u200cడయాక్సైడుతో'),
#  ('సజల కుప్రస్', 'అగును', 'ద్రావణులు క్షారాలతో'),
#  ('టెస్ట్ బెనెడిక్ట్స్', 'మూలలక్షణము', 'పరీక్ష'),
#  ('కుప్రస్ఆక్సైడును రంగులు', 'ఉపయోగిస్తారు', 'పరిశ్రమలలో'),
#  ('1924 కాలంలో', 'ఉపయోగించెవారు', 'ఆక్సైడును'),
#  ('బెనేడిక్టు పరీక్షలో', 'ఏర్పడును', 'ఆక్సైడు'),
#  ('రంగలోయ విశాఖపట్నం', 'గ్రామం', 'జిల్లా మండలానికి'),
#  ('బాలబడి పెదబయలులోను', 'ఉన్నాయి', 'రూడకోటలోనూ'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల పాడేరులోనూ'),
#  ('సమీప వైద్య', 'ఉన్నాయి', 'కళాశాల పాడేరులోనూ'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'అనకాపల్లిలోను'),
#  ('సంచార వైద్య', 'లేరు', 'శాలలో'),
#  ('మురుగునీటిని శుద్ధి', 'పంపిస్తున్నారు', 'ప్లాంట్\u200cలోకి'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('నియోజకవర్గాల పునర్వ్యవస్థీకరణ', 'మార్పులేదు', '2007లో భౌగోళిక స్వరూపంలో'),
#  ('గతంలో అనంతపురం', 'భాగమైనాయి', 'నియోజకవర్గంలో నియోజకవర్గంలో'),
#  ('అనంతపురం లోక్\u200cసభ', 'సాధించారు', 'నియోజకవర్గంలో ఎన్నికలలో'),
#  ('2002 లోక్\u200cసభ', 'చేస్తున్నాడు', 'ఎన్నికలలో తరఫున'),
#  ('ఎస్ మన్సూర్', 'ఉన్నాడు', 'పోటీలో'),
#  ('పౌరుష గ్రంథి', 'ఉంటుంది', 'పీఠభాగంలో'),
#  ('క్షార పదార్థం', 'చేస్తుంది', 'శుక్రకణాలను'),
#  ('పౌరుష గ్రంధి', 'ఉత్పత్తిచేస్తుంది', 'పాలవంటి ద్రవాన్ని'),
#  ('భాగం శుక్రకణాలు', 'కలిసియుంటుంది', 'కోశాల క్షారంగా'),
#  ('యోనిలోని ఆమ్లత్వాన్ని', 'పొడిగిస్తాయి', 'జీవితకాలాన్ని'),
#  ('పౌరుష గ్రంధి', 'జీవిస్తాయి', 'రావాలు స్కలితంలో శుక్రకణాలతో'),
#  ('గ్రంధి చుట్టూ', 'తోడ్పడతాయి', 'బయటికి'),
#  ('పౌరుష గ్రంధి', 'ఉంటాయి', 'జాతుల్లో'),
#  ('ఇవి చక్కెరలను', 'కలిగివుంటుంది', 'ఆమ్లత్వాన్ని'),
#  ('ఇవి జింకు', 'ఉంటుంది', 'రక్తంలో'),
#  ('2002 సంవత్సరంలో', 'గుర్తించారు', 'దీనిని'),
#  ('పురుషులలో స్త్రీల', 'వస్తాయి', 'బయటికి'),
#  ('ప్రోస్టేట్ స్పెసిఫిక్', 'స్రవిస్తుంది', 'ఆంటీజెన్'),
#  ('దీర్ఘకాలిక ప్రోస్టేటైటిస్', 'బాధిస్తుంది', 'కటిప్రాంతంలో'),
#  ('పౌరుష గ్రంధిని', 'ప్రయత్నించవచ్చును', 'వైద్యం'),
#  ('శస్త్రచికిత్స అవసరం', 'అవుతుంది', 'ఎక్కువమందికి'),
#  ('సూది మైక్రోవేవ్', 'కాల్చవచ్చును', 'లను వేడిమితో'),
#  ('ప్రసేకం పరికరాన్ని', 'తొలగిస్తారు', 'మూత్రానికి'),
#  ('దీనికి తొందరా', 'ఉపకరిస్తాయి', 'వేలితో రక్తంలో'),
#  ('ఉత్తమ విదేశి', 'జరిగింది', 'విభాగంలో అవార్డుకు'),
#  ('చివరికి నేషన్\u200cవైడ్', 'దారితీసింది', 'భారతదేశంలో'),
#  ('మాచీ పత్రి', 'చెందినది', 'మాఛిపత్రి'),
#  ('నేత్రవ్యాధులు జ్వరాలను', 'ఉపయోగపడుతుంది', 'నివారణకు'),
#  ('వలసీకరణకు జాతీయ', 'గుర్తించబడుతుంది', 'ఆవిర్భావానికి భూభాగంలో బృందాలతో'),
#  ('ఐక్యరాజ్యసమితి అంతర్జాతీయ', 'ఏర్పర్చబడ్డాయి', 'సంస్థల'),
#  ('ఐక్యరాజ్యసమితి హక్కుల', 'లక్ష్యం', 'వనరులకు'),
#  ('అంతర్జాతీయ శాసనం', 'నిర్దేశిస్తున్నాయి', 'సరిహద్దుల పద్ధతులలో'),
#  ('బృందాలకు విలక్షణతను', 'ఉంటుంది', 'సూత్రబద్ధ అర్థంలో'),
#  ('ప్రయోజనాల మూలవాసులు', 'పొందుపర్చబడుతుంది', 'దీనిని'),
#  ('దేశీయేతరకి చర్చను', 'వీక్షించవచ్చు', 'నేపథ్యంలో'),
#  ('మంది ప్రత్యేక', 'ఉన్నారు', 'దీంట్లో'),
#  ('ప్రజారాసులు నాటకీయ', 'అంతరించిపోతున్నారు', 'పతనం చివరకి'),
#  ('ప్రపంచంలోని ప్రాంతాలలో', 'ఉన్నారు', 'ప్రమాదంలో'),
#  ('కొంతమంది ప్రజారాసులలో', 'లోనయ్యారు', 'మార్పులకు'),
#  ('సందర్భాలలో ప్రజారాశులు', 'విస్తరిస్తున్నారు', 'యధాస్థితికి'),
#  ('మూలవాసుల సమాజాలు', 'ఏర్పర్చుకుంటాయి', 'నివాసాన్ని'),
#  ('శీతోష్ణ మండలం', 'చూడవచ్చు', 'ఖండంలోనూ'),
#  ('వాసులు సాంస్కృతిక', 'ఉంటారు', 'బృందాలతోనూ'),
#  ('వాసుల పరిస్థితులు', 'వివరించారు', 'ప్రపంచంలోని ప్రాంతాలలో విధంగా'),
#  ('మూలవాసులకు మూలవాసేతర', 'ఉంటుంది', 'సమాజాలకు సంక్లిష్టంగానూ'),
#  ('పురాతత్వ శాస్త్ర', 'చేస్తుంది', 'ప్రజానీకంతో'),
#  ('అక్కడి వనరులపై', 'తీస్తుంది', 'ఆధిపత్యానికి'),
#  ('సమాజాలు కొత్త', 'అంశమే', 'ప్రాంతాలలో'),
#  ('చరిత్రలో సంఘటనలే', 'దోహదమయ్యాయి', 'సంస్కృతుల'),
#  ('స్థితి వాసుల', 'ఉండవచ్చు', 'ఆధారాలతో'),
#  ('గ్రీకుల ప్రామాణిక', 'తెలుపుతున్నాయి', 'కాలానికి'),
#  ('పాలస్గియనుల', 'పిలిచారు', 'వాటిలో వీరిని'),
#  ('ప్రజలు ఏజియన్', 'పేర్కొన్నారు', 'ప్రాంతాలలో ప్రాంతానికి'),
#  ('సమూహపు స్వభావము', 'దొరకడంలేదు', 'గుర్తింపుకు'),
#  ('హోమర్ హోసియాడ్', 'ఉన్నాయి', 'రచనలలో'),
#  ('రోమన్ సమాజ', 'కొనసాగింది', 'ఆధిపత్యం'),
#  ('కాలంలో విజయాల', 'వచ్చింది', 'దాని ఆధీనంలోకి'),
#  ('ప్రామాణిక పురాతనత్వ', 'సంస్కృతి', 'ప్రాంతాలలో'),
#  ('రోమన్ ప్రపంచంలో', 'ఉండేది', 'సంస్కృతితో'),
#  ('గ్రీకో రోమన్', 'తలెత్తాయి', 'సరిహద్దులలోసమస్యలు'),
#  ('ప్రపంచంలోని ఆసియా', 'కొత్తవి', 'ప్రాంతాలలో రకమైన'),
#  ('భావనకు మూలాలు', 'ఉన్నాయి', 'నిజానికి భావజాలాలలో'),
#  ('ప్రజలు సంస్కృతి', 'ప్రదర్శించారు', 'రీత్యా సంస్కృతితో విభేదాన్ని'),
#  ('రోమన్ ప్రపంచంలో', 'ప్రతిఫలించింది', 'నిర్ణయంలోనూ'),
#  ('స్వప్రయోజనాలను ప్రతిఘటనల', 'సాహసించాయి', 'తనను'),
#  ('గ్రీకో రోమన్', 'గురయ్యాయి', 'ప్రభావాల'),
#  ('వాసుల ప్రతిఘటనకు', 'ఒకటి', 'సంఘటనలలో'),
#  ('సాహసోపేతమైన సాంస్కృతిక', 'చేసింది', 'రోమ్\u200dను'),
#  ('సంబంధాలలోకి వాసుల', 'ఏర్పడింది', 'దీని'),
#  ('అమెరికా ఆఫ్రికా', 'తీసాయి', 'సంఘర్షణలకు'),
#  ('మూలవాసులు భూగోళంలోని', 'ఉన్నారు', 'ప్రాంతాలలోనూ'),
#  ('మధ్యప్రాచ్యం అరేబియన్', 'ఉంటున్నాయి', 'యుగాలనుంచి ప్రాంతంలో'),
#  ('అరబ్ ఆఫ్రికా', 'గుర్తించబడవు', 'దక్షిణాఫ్రికా'),
#  ('పురాతన దక్షిణ', 'కనిపిస్తాయి', 'యెమెన్\u200cలలో'),
#  ('ఇస్లాం కారణాలతో', 'వచ్చింది', 'పిల్లలకు మానవుడికి'),
#  ('చారిత్రకంగా సంస్కృతీపరమైన', 'పిలవబడుతుంటారు', 'సమానార్థంలో'),
#  ('వీరిలో పౌరసత్వాన్ని', 'పొందారు', 'సహజీకరణ'),
#  ('విదేశీ బృందాలు', 'భావించబడుతోంది', 'సాపేక్షికంగా'),
#  ('సాధారణ శాసనం', 'లేదు', 'సామీప్యంలోని స్థానిక'),
#  ('పురాతన అరబ్బు', 'ఒకటి', 'తెగలలో'),
#  ('వలసానంతర దశలో', 'ఉన్నాయి', 'ఖండంలో ప్రజలకు వెనక్కి'),
#  ('జాతి ఆధిపత్య', 'ఉంటారు', 'నిర్మాణాలనుంచి'),
#  ('శతాబ్ది చివరినుంచి', 'వచ్చారు', 'గుర్తింపును'),
#  ('ఆఫ్రికా ప్రజల్లోని', 'గుర్తించబడతారు', 'ఖండానికి ప్రాంతానికి అర్థంలో'),
#  ('ఆఫ్రికన్ జాతి', 'ప్రకటించుకోలేదు', 'నిబంధనలకింద గుర్తింపును'),
#  ('చారిత్రక వాతావరణ', 'ఘర్షించాయి', 'పరిస్థితులతో వ్యవస్థలకు విధానాలతో'),
#  ('ఆఫ్రికాలోని మానవ', 'ఉండదు', 'సంక్లిష్ట చరిత్రలో'),
#  ('ఉదాహరణకు సాహెల్', 'ఏర్పర్చుకున్నాయి', 'కాలంలో ప్రాంతాల్లోనే'),
#  ('మూలవాస స్థితిపై', 'ఆధారపడింది', 'పరిమితీకరణపై'),
#  ('ఆఫ్రికా సహకార', 'ఒకటి', 'చర్చలలో'),
#  ('ఆఫ్రికాలోని మూలవాసుల', 'గుర్తిస్తుంది', 'ప్రకటనలతో IPACC'),
#  ('గవర్నమెంటల్ మూలవాసుల', 'చేపడుతుంది', 'హక్కులపై ఆప్రికన్ ఆధ్వర్యంలో'),
#  ('దీన్ని ఆఫ్రికన్', 'సమర్పించింది', 'యూనియన్'),
#  ('కమ్యూనిటీలపై ఆఫ్రికన్', 'స్వీకరించాయి', 'ప్రతిపాదనలను'),
#  ('నివేదికను స్వీకరించడం', 'ఉంటుంది', 'జాతీయవ్యాప్తంగా'),
#  ('అమెరికన్ ఖండాలలోని', 'ఉన్నారు', 'విస్తృతార్థంలో ప్రాంతంలో'),
#  ('మూలవాసుల సముదాయాలపై', 'వచ్చారు', 'అమెరికాలో'),
#  ('ఉత్తర దక్షిణ', 'ఉంటున్నాయి', 'అమెరికాలోని సరిహద్దుల'),
#  ('దేశాలలో దేశాలలో', 'ఉన్నారు', 'ప్రజానీకంలో'),
#  ('ప్రత్యేకించి ఉరారినా', 'ఉపయోగిస్తున్నారు', 'సమాజాల్లో'),
#  ('కెనడాలోని మూలవాసులు', 'ఉంటున్నారు', 'మెటిస్లతో'),
#  ('" ఇండియన్', 'పోతున్నాయి', 'కెనడాలో'),
#  ('కెనడాలో 600వరకు', 'చెందిన', 'బాండ్\u200cలుకు'),
#  ('జాతీయ మూలవాసీ', 'గుర్తిస్తోంది', 'దినం చరిత్రకు చేర్పులను'),
#  ('న్యునావిక్ న్యునాట్సియవుట్', 'సాధించింది', 'భూభాగంలో'),
#  ('% 000', 'ఉన్నారు', 'ప్రజలను'),
#  ('మూలవాసులు బ్రెజిల్', 'ఉత్తర', 'భూభాగంలో'),
#  ('పశ్చిమ భాగపు', 'ఉంటున్నారు', 'ప్రాంతాల్లో'),
#  ('2007 జనవరి', 'నిర్ధారించింది', '18న బ్రెజిల్\u200cలో'),
#  ('దీనికి బ్రెజిల్', 'అధిగమించింది', 'తెగలతో'),
#  ('మూలవాసులను గణాంకాలను', '%', 'దానిపై ప్రపంచంలో మూలవాసులలో'),
#  ('సరిహద్దులలోపల షెడ్యూల్డ్', 'గుర్తించింది', 'రాజ్యాంగబద్దంగానే'),
#  ('నివిక్ ప్రజలు', 'పడింది', 'సఖాలిన్\u200cకి కొద్దిమంది ప్రమాదంలో'),
#  ('ఐనూ ప్రజలు', 'చెందినవారు', 'బృందానికి'),
#  ('జపనీస్ వలసలు', 'తోసివేయబడ్డారు', 'ఉత్తరానికి'),
#  ('స్థానిక ఆమెరికన్లను',
#   'నిర్భంధించింది',
#   'ప్రాంతాల్లో హోక్కైడోలోని ప్రాంతంలో'),
#  ('ఫిలిప్పైన్స్ మూలవాసులు', 'వలసీకరించబడ్డారు', 'స్పెయిన్ స్టేట్స్\u200cచే'),
#  ('లోరెస్టన్ ఇల్లామ్', 'ఉంటున్నారు', 'ప్రావెన్స్\u200cలతో సరిహద్దుకు'),
#  ('బహ్రానీలు బహ్రెయిన్', 'మూలవాసులు', 'ద్వీపకల్పంలోని అరేబియాకు'),
#  ('చరిత్రలో ఐరోపా', 'పరిగణించవచ్చు', 'శక్తులచేతిలో'),
#  ('అంతర్జాతీయంగా గుర్తింపు', 'తెచ్చాయి', 'ముందుకు'),
#  ('వ్యాసంలో వాస', 'వాడబడింది', 'సంకుచితార్థంలో'),
#  ('యురేషియా కల్పానికి', 'నివసిస్తున్నారు', 'ఉత్తరభాగంలో ప్రాంతాలలోనూ'),
#  ('ఉత్తర స్కాండినేవియాలోని', 'గుర్తింపదగినవారు', 'వాసులలో'),
#  ('ఉత్తర స్పెయిన్\u200dలో', 'ప్రజానీకం', 'ఫ్రాన్సులో'),
#  ('బాస్క్యూ ఐరోపా', 'సమూహం', 'కొత్త'),
#  ('యూరోపియన్ భాషలు', 'ప్రజలు', 'ప్రాంతంలోనికి'),
#  ('ఫ్రాంకో కాంటాబ్రియన్', 'ప్రజలు', 'ప్రాంతంలో'),
#  ('మెగ్డాలియన్ కాలం', 'నివసిస్తున్నారు', 'ప్రాంతంలో'),
#  ('బాస్క్యూ దేశంలోనికి', 'కిందటిది', 'చొరబాటుని'),
#  ('మానవుడు ఐరోపాలోనికి', 'చెందాడు', 'నియాండర్తలెన్సిస్\u200cగా'),
#  ('ఓషియానియా ప్రాంతంలోని', 'ఉండేవి', 'నేటి ప్రజలతో'),
#  ('పసిఫిక్\u200c ప్రాంతంలో', 'వచ్చింది', 'కిందికి'),
#  ('శతాబ్దిలో మాజీ', 'ఏర్పడినాయి', 'వలసలలో నియంత్రణలో'),
#  ('దీనికి ఉదాహరణలు', 'వంటివి', 'గ్వామ్\u200cకి ఐలాండ్స్\u200cకి'),
#  ('మంది మరుగుజ్జు', 'కనుగొన్నారు', 'దీవులలో'),
#  ('జనాభా పాక్షికంగా', 'గుర్తించబడుతున్నారు', 'మూలవాసీలుగా'),
#  ('మవోరీ పోలినేసియా',
#   '1000',
#   'మూలవాసులు సాపేక్షికంగా ఇటీవలే న్యూజిలాండ్\u200cలో'),
#  ('సంభవించి', 'భావిస్తున్నారు', 'CE'),
#  ('న్యూజిలాండ్\u200cలో రహిత', 'మారిపోయారు', 'సముదాయంలోకి అమరికకు'),
#  ('మవోరీ గిరిజన', 'భౌగోళిక', 'బ్రిటిష్ వారితో'),
#  ('రాజకీయ భూభాగమైన', 'స్థాపించబడింది', 'సమ్మతితో'),
#  ('సంతకాలు వైటాంగై', 'లేదు', 'ఇంగ్లీషు'),
#  ('ఒడంబడిక ప్రక్రియ', 'ఇచ్చింది', 'జనాభాకు పౌరసత్వాన్ని'),
#  ('బ్రిటిష్ వలస', '95', 'వైటాంగై'),
#  ('మవోరీలు రాజకీయ', 'స్థాపించుకున్నారు', 'పార్టీని'),
#  ('పాపువా న్యూ', 'ఉన్నాయి', 'సమాజాల్లోని'),
#  ('వాసుల సమూహాలకు', 'కొనసాగుతున్నాయి', 'సంస్థలకు వినియోగానికి వినియోగానికి'),
#  ('అనుభవాలు మూలవాసుల', 'లేదు', 'అనుభవంలోకి'),
#  ('వాసుల అనుభవాలలో', 'ఎదుర్కొంటున్నారు', 'వారితో ప్రాంతంలోకి'),
#  ('అంశాలు మూలవాసులు', 'ఉంటాయి', 'సంస్కృతికి'),
#  ('పరిసరాలలో సమాజాలతో', 'ఉంటాయి', 'బాధకు'),
#  ('వాసుల భూమి', 'ఏర్పడింది', 'ప్రమాదంలో'),
#  ('ప్రమాదావస్థలో వాసుల', 'ఇవ్వబడ్డాయి', 'చివర'),
#  ('రష్యన్ రాజ్యంలో', 'ఉన్నారు', 'ప్రాంతాలను'),
#  ('కెనడాలోని ఇనూట్', 'చెందుతారు', 'కోవకే'),
#  ('దీనికి ఉదాహరణ', 'బహిష్కరించింది', 'ప్రాంతాల'),
#  ('స్థానిక ప్రభుత్వపు', 'పోల్చాడు', 'నషా చర్యతో'),
#  ('2006 బోట్సువానా',
#   'తీర్పునిచ్చింది',
#   'సెంట్రల్ కలహారీ ప్రాంతాలకు మెన్\u200cలు'),
#  ('వాటికి వాసుల', 'ఉన్నాయి', 'ప్రభుత్వంతోనూ చర్చలలో'),
#  ('1994 23న', 'ప్రకటించింది', 'దినంగా'),
#  ('రెండవ ప్రపంచ', 'నిర్ణయించింది', 'దినోత్సవంగా'),
#  ('మనం ఆరవ', 'సూచిస్తుంది', 'దేశంలో'),
#  ('చారిత్రకంగా వాసుల', 'ఉంటాయి', 'ప్రాంతంలో ప్రాంతంలో'),
#  ('వాసుల సంస్కృతికి', 'తీర్చిదిద్దుతుంది', 'ప్రాంతంలో'),
#  ('లక్షణం ఆధునిక', 'పొందుతాము', 'కాలంలో ప్రాంతంతో'),
#  ('వాసుల సంస్కృతి', 'వర్తించదు', 'ప్రాంతాలకు సందర్భాలకు'),
#  ('వాసుల ఙ్ఞానాన్ని', 'చేసుకోవచ్చు', 'వనరులతో'),
#  ('వాసులు జీవ', 'గురౌతున్నారు', 'చౌర్యానికి'),
#  ('సాంస్కృతిక ప్రాంతీయ', 'ఉంటాయి', 'నేపథ్యాలనుండి'),
#  ('బలమూ బలహీనతలు', 'ఉంటాయి', 'విధానంపై'),
#  ('దృక్కోణాలు సంబంధాలను', 'పరిశీలిస్తాయి', 'వైపుల'),
#  ('ఉష్ణమండల ప్రాంత', 'పడుతున్నాయి', 'నిర్మూలన దీనికి ప్రమాదంలో'),
#  ('స్వాంగీకారక వలసవాద',
#   'ప్రతిఫలిస్తున్నాయి',
#   'విధానాలు పిల్లల రక్షణకు సమస్యలలో'),
#  ('అదే ప్రామాణక', 'తగ్గుతూవచ్చింది', 'పురాతనకాలానికి పక్షానికి'),
#  ('థామస్ హాబ్స్', 'మొగ్గుచూపారు', 'క్రూరస్వభావులుగా వైపు'),
#  ('హాబ్స్ దృక్పధానికి', 'వచ్చారు', 'మూలవాసులను'),
#  ('ప్రత్యేకించి యూరప్\u200cకి', 'వర్తించేవారు', 'సంస్కృతులకు'),
#  ('ప్రకృతికి ప్రజా', 'గుర్తిస్తోంది', 'ప్రపంచంపై'),
#  ('ప్రమాద భయాలు', 'పుట్టుకొస్తున్నాయి', 'ఇక్కడినుంచే'),
#  ('అదేసమయంలో వలసవాద', 'వచ్చారు', 'ఉద్యమం'),
#  ('మూస Indigenous', 'continentమూస', 'peoples by'),
#  ('బాలబడి రామన్నపేటలోను', 'ఉన్నాయి', 'ఎన్నారంలోనూ'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల చెర్లపల్లిలోనూ'),
#  ('సమీప వైద్య', 'ఉన్నాయి', 'కళాశాల కళాశాల నల్గొండలోనూ'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'నల్గొండలోనూ'),
#  ('డిగ్రీ డాక్టరు', 'ఉన్నారు', 'ఒకరు'),
#  ('గ్రామంలో కుళాయిల', 'జరుగుతోంది', 'సరఫరా'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('మురుగునీటిని శుద్ధి', 'పంపిస్తున్నారు', 'ప్లాంట్\u200cలోకి'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('జిల్లా రహదారి', 'పోతోంది', 'గ్రామం'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('తుర్కపల్లిలో భూ', 'బి', 'వినియోగం'),
#  ('తెలుగు తమిళ', 'నటించింది', 'సినిమాల్లో పాత్రలలో'),
#  ('2015 నాటికి', 'నటించింది', 'సినిమాలకు'),
#  ('బడిలో చదివేటపుడే', 'పాల్గొనేది', 'కార్యక్రమాల్లో'),
#  ('తరగతిలో విజయవాడలోని', 'వ్యవహరించింది', 'ప్రాంతీయ ఛానల్లో'),
#  ('పెళ్ళైన భర్తతో', 'వ్యవహరించింది', 'దర్శకత్వంలో కార్యక్రమానికి'),
#  ('బిహారి మల్', 'తండ్రి', 'మొఘలు చక్రవర్తి'),
#  ('బిహారి మల్', 'చంపబడ్డాడు', 'యుద్ధంలో'),
#  ('రాజా పృథ్వీరాజ్', 'అధిష్టించాడు', 'కుమారుడు వంశానికి రాణికి సింహాసనం'),
#  ('మొఘలు చక్రవర్తి', 'మరణించారు', 'హుమయూనుకు బయానా కోటను యుద్ధంలో'),
#  ('సమయంలో అతను', 'లేదు', 'వయస్సులో'),
#  ('పూరరణ్ మాల్', 'అధిష్టించాడు', 'అధికారపీఠం'),
#  ('అధికారం సుజమల్', 'పొందాడు', 'కుటుంబంలో ఆశ్రయం'),
#  ('భీమ్ సింగ్', 'చేపట్టాడు', 'సింగ్ అధికారం'),
#  ('న అస్కరనును', 'చేసారు', 'పదవి పాలకుడుని'),
#  ('1527 బిహారీ', 'ఉన్నాయి', 'సోదరుడు'),
#  ('రానా నాయకత్వంలోని', 'ఎదురైంది', 'యుద్ధంలో నష్టాన్ని'),
#  ('ముస్లిం పాలకులు', 'పొందారు', 'వెలుపలకు'),
#  ('మొఘలులు పురాణ్', 'గ్రహించారు', 'వ్యక్తిగా'),
#  ('పురాణ్ మల్', 'ఉన్నాడు', 'మొఘలులకు సేవలు'),
#  ('రాజపుతానాలో కచ్వాహాలు', 'అయ్యారు', 'మిత్రరాజ్యాలు'),
#  ('మొఘలుల బిహారి', 'అయింది', 'సోదరుడి'),
#  ('బహదూర్ షా', 'అనుసరించాడు', 'విధానాన్ని'),
#  ('టాటర్ ఖాన్', 'పంపాడు', 'లోడికి కోటను'),
#  ('బాబర్ కాలం', 'ఆక్రమించుకున్నాడు', 'ఆక్రమణలో కోటను'),
#  ('హుమాయున్ అస్కారి', 'పంపించాడు', 'కోటను'),
#  ('1534 అంబరు', 'పాల్గొన్నాడు', 'లో'),
#  ('సంవత్సరం గుజరాతు', 'చుట్టుముట్టారు', 'కోటను'),
#  ('హుమాయును బహదూరు', 'ప్రారంభించాడు', 'షాకు వ్యతిరేకంగా'),
#  ('సకాలంలో కర్మవతికి', 'అయ్యేవారు', 'మిత్రవర్గం'),
#  ('కోటలో స్త్రీలు', 'మరణించారు', 'జౌహరులో యుద్ధంలో'),
#  ('నమోదు రికార్డు', 'భావిస్తున్నారు', 'సూత్రాలను'),
#  ('బారా కోటిస్', 'కలిగింది', 'నాయకత్వంలొ సమయంలో'),
#  ('మేధావి అక్బర్', 'అందించారు', 'విధానంతో'),
#  ('కచ్వాహుల మద్దతు', 'మారింది', 'సామ్రాజ్యంగా'),
#  ('ఔరంగజేబ్ పాలన', 'జరగలేదు', 'ప్రాంతంలో యుద్ధం'),
#  ('1556 మొఘల్', 'చేసాడు', 'ఖ్వాఖ్షాలుకు'),
#  ('మజునాన్ ఖాను', 'తెలియజేసాడు', 'అక్బరుకు'),
#  ('బిహారీ మాలును', 'సత్కరించాడు', 'ఢిల్లీ'),
#  ('సుజమల్ అమెర్', 'తెలిపాడు', 'సభకు చేరుకుని సింహాసనాన్ని మద్దతును'),
#  ('మీర్జా అంబరుకు', 'నడిపించాడు', 'సైన్యాన్ని'),
#  ('కచ్వాహాస్ అంబరును', 'చేసాడు', 'నివసించాలని వత్తిడి'),
#  ('బీహారీ మీర్జాకు', 'ఉంచాడు', 'మిర్జాస్వాధీనంలో'),
#  ('ఉద్ డిన్', 'కలుసుకున్నాడు', 'చాఘాటై ఖానును'),
#  ('అంబరు రాజా', 'ఉన్నాడు', 'ఆగ్రా మార్గంలో'),
#  ('చంఘాటై ఖాను', 'వేడుకున్నాడు', 'మల్ అక్బరును'),
#  ('అక్బరు రాజా', 'పిలిచాడు', 'సభకు'),
#  ('బిహారి మల్', 'కలుసుకున్నారు', 'దౌసాలో అక్బరును'),
#  ('సంగనేర్ శిబిరంలో', 'కలుసుకున్నాడు', 'అక్బరును'),
#  ('చంఘాటై ఖాను', 'చేసాడు', 'బంధువులను'),
#  ('బీహారీ మాల్', 'ప్రతిపాదించారు', 'అక్బరుకు'),
#  ('అక్బరు అందుకు', 'ఆదేశించాడు', 'చంఘాటై ఖానును'),
#  ('అక్బరు అజ్మీరు', 'లొంగిపోయాడు', 'అక్బరుకు'),
#  ('బిహారీ శంభరుకు', 'ఫిబ్రవరి', 'మాల్'),
#  ('న కుమార్తెను', 'చేసాడు', 'అక్బరుకు'),
#  ('అక్బరు కొత్త', 'వచ్చారు', 'అతడి శిబిరానికి'),
#  ('మాన్ సింగ్', 'అప్పగించబడ్డాదు', 'ఆయనకు'),
#  ('అక్కడి భగవంత్', 'వచ్చారు', 'అక్బరుతో ఆగ్రాకు'),
#  ('బలిజలు ఆర్యావర్తనంలోని', 'వచ్చినారు', 'అహిచ్ఛత్రపురము శాసనాలలో'),
#  ('నేటి కర్ణాటకలోని', 'విస్తరించారు', 'వంశీయులకు దక్షిణాది'),
#  ('నావికాదళాలతో తూర్పుదేశాలలో', 'ఏర్పాటుచేసుకొనెను', 'స్థావరాలు'),
#  ('వీర బలిజ', 'కలిగినవారు', 'ప్రతిపాలకులు కులపెద్దలుగా శాసనాలలో'),
#  ('యజ్ఞ సంభవులవుట', 'పిలువబడినారు', 'పేరుమీద'),
#  ('చాళుక్య చోళ', 'పేర్కొనబడినారు', 'బలిజవారిలో'),
#  ('బలిజవారు సంవత్సరాల', 'ఉన్నది', 'పరిపాలనలలో'),
#  ('ఋగ్వేదం రామాయణం', 'వర్ణించబడినారు', 'వాఙ్మయాలలోనూ'),
#  ('దేశాలలో దేశాల', 'పిలవబడతారు', 'పేర్లతో'),
#  ('విజయనగర కాలంనాటికి',
#   'పిలువబడినారు',
#   'సంపదలతో మార్పులతో ప్రాంతములో జిల్లాలలో గ్రామాలలో'),
#  ('కులాల్లో చేర్చాలని', 'చెబుతున్నారు', 'వెనుకబడి'),
#  ('స్కాలర్షిప్పులు మంజూరు', 'చేసింది', 'ల'),
#  ('కాపులు అనేవారు', 'తెలియజెబుతుంది', 'సీమాంధ్ర తెలంగాణకు'),
#  ('కాపులు 1871నుండి', 'ఉన్నారు', 'నిజానికి'),
#  ('నేటికీ కాపులు', 'పిలుస్తారు', 'వీరందరిని'),
#  ('తీరాంధ్రలోని శ్రీకాకుళం', 'పేర్కొన్నారు', 'వర్గంనుండి'),
#  ('తీరాంధ్రలోని శ్రీకాకుళం', 'మార్చుకున్నారు', 'జిల్లాలలో కర్ణాటకలో'),
#  ('భారత రాష్ట్రపతి', 'గౌరవిస్తారు', 'రంగాలలో పతకమునిచ్చి'),
#  ('చివుకుల జొగి', 'రాజకీయవేత్త', 'జాతికి'),
#  ('డెమోక్రటిక్ పార్టీ', 'ఎన్నుకోబడినాడు', 'సభ్యుడిగా'),
#  ('ఫ్రాంక్లిన్\u200cటౌన్\u200cషిప్\u200cకు డెప్యూటీ',
#   'పనిచేశారు',
#   'శాసనసభ్యుడుగా ఉపసభాపతిగా'),
#  ('2001 నూజెర్సీ', 'పౌరుడు', 'స్థానానికి భారతసంతతికి'),
#  ('ఇంట్లో తెలుగు', 'వచ్చు', 'అందరికీ'),
#  ('వ వార్డు', 'అయ్యాడు', 'సభ్యుడిగా'),
#  ('2001', '5', 'అటుపిమ్మట'),
#  ('వవార్డు కౌన్సిల్', 'ఎన్నుకోబడ్డాడు', 'సభ్యుడిగా'),
#  ('ఈయన నగర', 'అందించాడు', 'సేవలు'),
#  ('కాపురం కొత్త', 'లోనిది', 'సినిమా'),
#  ('పాకలో ఉన్నా', 'కలిగించేదే', 'పసిడి మండుటెండలో నీడగా'),
#  (': చీకటిలో', 'నీడలొక్కటిగా', 'బాధలలో కలిమిలో'),
#  ('భాషను దేవనాగరి', 'వ్రాస్తుంటారు', 'లిపిలో'),
#  ('1932లో పాలము', 'నిర్వహించారు', 'ఆరణ్యాలలో'),
#  ('సామెతలు లోకోక్తులు', 'వాక్యాలు', 'భాషలో'),
#  ('" సామెత', 'అంటారు', 'మాట'),
#  ('సామెతలకు రచయితగా', 'చెప్పలేము', 'ఒక్కరినీ'),
#  ('ప్రజలు అనుభవాల్లోనుంచే', 'పుట్టిస్తారు', 'సామెతలను'),
#  ('సామెతను పాలల్లో', 'కలిపినట్లుంటుంది', 'పంచదార'),
#  ('ఇవి జాతి', 'చెబుతుంటాయి', 'నాగరికతను'),
#  ('కార్యోన్ముఖులను ప్రమాదమును', 'హెచ్చరించవచ్చును', 'వ్యక్తులను'),
#  ('సంక్షిప్తమైన వివరణ', 'వ్రాయవచ్చును', 'పేజీలోనే'),
#  ('ప్రత్యామ్నాయ వైద్యంలో', 'చెప్పవచ్చు', 'నోటిలో'),
#  ('శాస్త్రీయ అధ్యయనాలు', 'సూచించాయి', 'బ్యాక్టీరియాకు'),
#  ('అభ్యాసకుడు ఖాళీ', 'చేయబడ్డాయి', 'కడుపుతో నూనెను'),
#  ('విధానం నూనె', 'మిళితమవుతుంది', 'లాలాజలంతో'),
#  ('నోటిలోకి తీసుకున్న', 'ఊయాలి', 'గెడ్డాన్ని పైకి'),
#  ('నూనె పసుపు', 'మారుతుంది', 'రంగు'),
#  ('విషాలు శరీరంలో', 'గుర్తించుకోండి', 'నూనెను బయటికి'),
#  ('నూనె చిక్కదనం', 'భావించాలి', 'శరీరంలోకి'),
#  ('ఆయిల్ పుల్లింగ్', 'ఉపయోగించాలి', 'దశను నూనెను'),
#  ('నూనె చిక్కదనం', 'భావిస్తున్నారు', 'అశుభ్రతను'),
#  ('నువ్వుల నూనె', 'నిర్వహించాలి', 'బ్యాక్టీరియా'),
#  ('అతివరం కొత్తపాలెంలో', 'జరుగుతోంది', 'వ్యవసాయానికి'),
#  ('మల్లనూరు చిత్తూరు', 'గ్రామము', 'జిల్లా మండలానికి'),
#  ('రాబర్ట్ సన్', 'ఉన్నాయి', 'సమీపములో'),
#  ('రోమన్ కాథలిక్', 'ఉంటుంది', 'స్వీకరించు'),
#  ('క్రైస్తవ చర్చి\u200cని', 'ఉపయోగించబడింది', 'ప్రపంచవ్యాప్త'),
#  ('క్రైస్తవ సంబంధం', 'ఉంటుంది', 'మతంతో'),
#  ('విస్తృతస్థాయిలో క్రిస్టియన్', 'ఉంటారు', 'విషయంలో'),
#  ('కాథలిక్ క్రిస్టెన్\u200cడోమ్\u200c', 'కలిగిఉంటారు', 'పరిథిలో'),
#  ('స్ముర్నా లోని', 'ఉంటోంది', 'ఆంటియోక్'),
#  ('క్రైస్తవ మత', 'బోధించేవారు', 'విశ్వాసంలో'),
#  ('కాథలిక్ క్రైస్తవులు', 'థియోడోసియస్', 'సామ్రాజ్యాన్ని'),
#  ('చక్రవర్తి కాలంలో', 'విశ్వసించబడుతోంది', 'చట్టంలోకి'),
#  ('మూఢత్వం కలిగిన', 'సాహసించం', 'ఇతరుల సభలకు'),
#  ('అగస్టెయిన్\u200cకు సమకాలీకుడైన', 'రచించాడు', 'పేరుతో'),
#  ('మానవ దేహం', 'ఉంచాలి', 'అదేసమయంలో రచనలో చర్చిలో'),
#  ('మనం సార్వజనికత', 'గ్రహించవచ్చు', 'నియమాన్ని'),
#  ('ప్రపంచవ్యాప్తంగా చర్చిలు', 'ఆచరించవచ్చు', 'ఒక విధంగానూ పురాతనత్వంలో'),
#  ('గతంలోని చర్చి', 'ఇరవై', 'ఫాదర్\u200cలు రూపంలో'),
#  ('తూర్పు కాథలిక్', 'ఉంటాయి', 'బిషప్\u200cతో'),
#  ('స్వయంప్రతిపత్తి కలిగి', 'చేస్తారు', 'తూర్పు'),
#  ('మలన్కారా చల్డియన్', 'ఉంటాయి', 'సైతం'),
#  ('పోప్ పాల్', 'అనేది', 'నేతృత్వంలో కాటెచిసమ్ విస్వాసాలకు'),
#  ('చర్చి పదం', 'మొత్తం', 'చర్చితో పాంటిఫ్\u200cగా'),
#  ('బిలియన్\u200c క్రైస్తవులు', 'ఉన్నారు', 'పోప్\u200cకి'),
#  ('క్రైస్తవ చర్చిలు', 'కనిపిస్తాయి', 'సమాజంలో'),
#  ('రకమైన చర్చిల', 'వెళ్లిపోయినవారు', 'సమాజంతో'),
#  ('రోమ్ బిషప్\u200cతో', 'సూచిస్తుంటాయి', 'రెండూ'),
#  ('క్రైస్తవులని వారంతా', 'ప్రము', 'చర్చిలో'),
#  ('చర్చి\u200cలతో కలిసి', 'కనిపిస్తుంది', 'కోణంలో తూర్పుతో'),
#  ('హోలీ కాథలిక్', 'ఉదాహరణ', 'కౌన్సిల్\u200cలో'),
#  ('రకమైన పత్రాల్లో', 'సూచించబడుతుంది', 'పేర్లతో'),
#  ('ఏంజెలికన్లు పురాతన', 'భావిస్తాయి', 'చర్చిలో'),
#  ('రోమన్ కాథలిక్',
#   'చూస్తాయి',
#   'సమాజంలో చర్చి\u200cలు పరిపాలన చర్చికి పాస్టర్\u200cగా'),
#  ('చర్చి ఊపిరితిత్తులతోనూ', 'జరుగుతోంది', 'తూర్పు చర్చిలతో'),
#  ('ప్రస్తుత పోప్', 'తెలిపారు', 'ఆర్థడాక్స్\u200cతో'),
#  ('మెథడిస్ట్\u200cలు ప్రెస్బైటేరియన్\u200cల',
#   'చెప్పుకోరు',
#   'విశ్వాసం అపోస్టెల్స్\u200cకు మూలాలకు'),
#  ('అయినప్పటికీ చర్చిలో', 'చెప్పుకుంటాయి', 'చర్చిలు'),
#  ('each Protestant', 'numbers', 'whatever the'),
#  ('necessary it', 'than', 'As further'),
#  ('చెప్పాలంటే అభిప్రాయాలు', 'అర్థం', 'ప్రపంచవ్యాప్తంగా'),
#  ('రోమన్ కాథలిక్', 'విభేదిస్తుంటాయి', 'పోపులు అంశాల్లో ప్రొటెస్టంట్ల'),
#  ('భీంగల్ తెలంగాణ', 'గ్రామం', 'మండలానికి'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల'),
#  ('సమీప వైద్య', 'ఉన్నాయి', 'నిజామాబాద్లోను కళాశాల ఆర్మూర్లోనూ'),
#  ('సమీప అనియత', 'ఉన్నాయి', 'నిజామాబాద్లోను ఆర్మూర్లోనూ'),
#  ('సంచార వైద్య', 'లేరు', 'శాలలో'),
#  ('గ్రామంలో కుళాయిల', 'జరుగుతోంది', 'సరఫరా'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('భీంగల్లో వ్యవసాయానికి', 'జరుగుతోంది', 'వనరుల'),
#  ('జాతరకు నిజామాబాద్', 'వస్తారు', 'తరలి'),
#  ('లక్ష్మీనరసింహారావు వారివలె', 'పేరుగాంచినారు', 'సారస్వతయుగంలో ఈయన'),
#  ('గురజాడ అప్పారావు', 'ఈయనొకరు', 'ఉత్సాహంతో యువకుల్లో'),
#  ('శార్వాణినగర్ శ్రీ', 'గ్రామము', 'మండలానికి'),
#  ('కుమారబొమ్మరాజుపురం చిత్తూరు', 'గ్రామము', 'జిల్లా'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'పుత్తూరులో మంగళంలోనూ'),
#  ('వైద్య కళాశాల', 'ఉన్నాయి', 'నగరిలోను'),
#  ('గ్రామంలో కుళాయిల', 'అవుతోంది', 'నీరు'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('కుమా రబొమ్మరాజుపురంలో', 'జరుగుతోంది', 'వనరుల'),
#  ('కుమా రబొమ్మరాజుపురంలో', 'అవుతున్నాయి', 'వస్తువులు'),
#  ('1969లో సాత్', 'నటించారు', 'సినిమాతో సినిమాలో'),
#  ('సినిమాల్లో విజయ్', 'నటించారు', 'పాత్రల్లో'),
#  ('సంవత్సరం అభిమాన్', 'నటించారు', 'సినిమాల్లో'),
#  ('నమక్ హరం', 'అందుకున్నారాయన', 'సినిమాకు ఫిలింఫేర్ పురస్కారం'),
#  ('యశ్ చోప్రా', 'అమితాబ్', 'దర్శకత్వంలో నటనకు'),
#  ('1975లో రమేష్', 'నిలిచింది', 'దర్శకత్వంలో'),
#  ('1976లో కభీ', 'అమితాబ్', 'చిత్రాల్లో'),
#  ('అమర్ అక్బర్', 'అందుకున్నారు', 'సినిమాకు నటుడు పురస్కారం'),
#  ('డాన్ సినిమాలో', 'అమితాబ్', '1978లో ద్విపాత్రాభినయంతో అభిమానులను'),
#  ('1980లో అమితాబ్', 'సినిమాల్లోనటించారు', 'విజయవంతమైన'),
#  ('దోస్తానా షాన్', 'చేసుకున్నాయి', 'విజయం'),
#  ('కాలియా సిల్', 'అమితాబ్', 'సినిమాల్లో'),
#  ('దోస్తానా శక్తి', 'లభించాయి', 'సినిమాల్లోని'),
#  ('ఏళ్ళు', 'ఉన్నారు', 'సినిమాలకు అమితాబ్'),
#  ('అగ్నిపథ్ ఫ్లాప్', 'అమితాబ్', 'సినిమాకు సినిమాతో'),
#  ('2000లో మొహొబ్బతేకు', 'అమితాబ్', 'సహాయనటుడు పురస్కారాం'),
#  ('సంవత్సరం కౌన్', 'పరిచయమయ్యారు', 'బుల్లితెరకు'),
#  ('2002లో ఆంఖే', 'అమితాబ్', 'సినిమాల్లో'),
#  ('2009లో సినిమాలోని', 'గెలుచుకున్నారు', 'నటుడు పురస్కారం'),
#  ('భూతనాథ్ భూతనాథ్', 'అమితాబ్', 'అభిమానులను'),
#  ('నట్వర్ లాల్', 'పాడారాయన', 'సినిమాల్లో'),
#  ('ఖైదీలు తోటి', 'చేసేవారు', 'ఖైదీలకు'),
#  ('బ్రాహ్మణ హోటల్', 'వాణ్ణి', 'గంటలకు రాత్రికి భోజనానికి'),
#  ('నెలల హోటల్', 'మానిపించాడు', 'నన్ను'),
#  ('మహాత్మా గాంధీజీ', 'చేశారు', 'ఉద్యమ పర్యటనలో ప్రాంతానికి'),
#  ('మహాత్మా గాంధీ', 'లభించింది', 'గారికి తెలుగులోనికి'),
#  ('శ్రీ యలమంచలి', 'వ్రాసారు', 'సంవత్సరాలు మార్గంలో స్పృహతో కళాశాలకు'),
#  ('విజయ వాడలోని', 'స్వీక్రించారు', 'శరీరాన్ని'),
#  ('నట జీవితం', 'తిరిగింది', 'వేషంతో'),
#  ('ఆడియో క్యాసెట్స్', 'సృష్టించాయి', 'అమ్మకాలలో'),
#  ('తెలుగు సినిమా', 'రూపునిచ్చారు', 'కొత్తదనానికి'),
#  ('డైలాగ్ మాడ్యులేషన్', 'చెప్పవలసినది', 'వీటిలో'),
#  ('వేటగాడు చిత్రంలో', 'కొల్లగొట్టుకున్నారు', 'పాత్రతో'),
#  ('గోపాలరావుగారి అమ్మాయి', 'కనిపిస్తుంది', 'చిత్రంలో'),
#  ('రంగస్థల నటుడుగా', 'రచించిన', 'రాధాకృష్ణ'),
#  ('నాటకంలోని పాత్రతో', 'అమెచ్యూర్\u200c', 'ప్రాముఖ్యత'),
#  ('కాకినాడ సమీపంలోని', 'జన్మించారు', '1937లో'),
#  ('కాకినాడలో ఆమె', 'పడ్డారు', 'హరికథ ప్రేమలో'),
#  ('2018 న', 'మరణించింది', 'హైదరాబాదులో'),
#  ('రావు గోపాలరావు', 'వి', 'నాటకాలను'),
#  ('రంగారావు గుత్తా', 'భక్తపోతన', 'రామినీడుకి'),
#  ('చిత్రానికి అసిస్టెంట్\u200c', 'పెట్టుకున్నారు', 'డైరక్టర్\u200cగా'),
#  ('చిత్రాలకు సహాయ', 'కిలాడీలు', 'దర్శకుడుగా'),
#  ('చిత్రానికి కంఠస్వరం', 'నిర్మాతలు', 'వేరొకరితో'),
#  ('బాపు దర్శకత్వంలో', 'గుర్తిండిపోతాయి', 'చిత్రాల్లోని'),
#  ('గుర్తుండి డైలాగ్స్\u200cని', 'ప్రదర్శించారు', 'చిత్రాల్లోనూ'),
#  ('పార్లమెంటు సభ్యునిగా', 'కొనసాగారు', 'ఆరేళ్ళపాటు'),
#  ('రావు గోపాలరావు', 'లు', 'అభినయానికి నాటకరంగంలో'),
#  ('పాత్రలోకైనా ఇట్టే', 'శైలి', 'పరకాయప్రవేశం'),
#  ('వాచకంతోనే పాత్రలకు', 'గోపాలరావు', 'జీవం'),
#  ('రావు గోపాలరావు', 'పలికారు', 'అభినయానికి వాచకానికి'),
#  ('బాపు రమణ', 'చేశారు', 'వాచకంలోని పాత్రల్లో'),
#  ('రావు గోపాలరావు', 'పలికించారు', 'సాంఘికాల్లోనే'),
#  ('మరపురాని పాత్రలు', 'అలరిస్తున్నారు', 'నటవారసునిగా నటనతో'),
#  ('తెలుగు ప్రతినాయకుల్లో', 'గోపాలరావు', 'నటవిరాట్ మదిలో'),
#  ('సంవత్సరంలో ఆంధ్ర', 'చేసింది', 'ఇతనికి విశ్వవిద్యాలయం'),
#  ('ఇతను నటుడుగా', 'తెఛ్ఛుకున్నాడు', 'పేరు'),
#  ('మగధీర కొత్త', 'పొందాడు', 'చిత్రాలతో గుర్తింపు'),
#  ('ఆహా 1998', 'చిత్రం', 'కృష్ణ దర్శకత్వంలో'),
#  ('జగపతి బాబు', 'నటించారు', 'ముఖ్యపాత్రల్లో'),
#  ('వందేమాతరం శ్రీనివాస్', 'వహించాడు', 'సంగీత దర్శకత్వం'),
#  ('ఇతను జీవితంలో', 'ఉంటాడు', 'అతన్ని'),
#  ('శ్రీరాం రామారావు', 'ప్రేమిస్తాడు', 'అమ్మాయిని'),
#  ('పరశురాం అంతస్తులో', 'అంగీకరించడు', 'సంబంధానికి'),
#  ('రఘురాం కాలేజీ', 'ఉంటుంది', 'చేరువలో'),
#  ('రఘురాం ఇంట్లో', 'వస్తుంటాడు', 'ఆమెను'),
#  ('శ్రీరాం విషయాన్ని', 'నిలదీస్తాడు', 'గీతను'),
#  ('ఆమె పరిస్థితికి', 'ఉంటాడు', 'రఘురాం'),
#  ('శ్రీరాం తను', 'కథ', 'అమ్మాయిని'),
#  ('గ్రామంలో ప్రైవేటు', 'ఉన్నాయి', 'ఒకటి'),
#  ('బాలబడి నిర్మల్లోను', 'ఉన్నాయి', 'మంజులాపూర్లోనూ'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల కళాశాల నిర్మల్లో'),
#  ('వైద్య కళాశాల', 'ఉన్నాయి', 'కళాశాల నిర్మల్లోనూ'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'నిర్మల్లో'),
#  ('గ్రామంలో కుళాయిల', 'జరుగుతోంది', 'సరఫరా'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'గంటల కోసం'),
#  ('కందిరీగలు హైమెనోప్టెరా', 'కీటకాలు', 'ఉపక్రమానికి'),
#  ('Parasitic wasps', 'increasingl', 'are'),
#  ('agricultural pest', 'crops', 'used have'),
#  ('జాతుల కందిరీగలు', 'కలిగివుంటాయి', 'లక్షణాలను'),
#  ('Parasitic wasps', 'increasingl', 'also'),
#  ('agricultural pest', 'crops', 'used have'),
#  ('Wasps also', 'chain', 'important the'),
#  ('కందిరీగ గూడును', 'అంటారు', 'ఆంగ్లంలో nest'),
#  ('కందిరీగలు కర్రను', 'నిర్మించుకుంటాయి', 'చెక్కను'),
#  ('గూడులలో కందిరీగలు', 'పరచుకుంటాయి', 'సంతానాన్ని అభివృద్ధి'),
#  ('కందిరీగలు గూడులలో', 'మూసివేస్తాయి', 'గ్రుడ్లను'),
#  ('గూడు మెత్తని', 'కందిరీగ', 'మట్టిని'),
#  ('చోడవరం ఆంధ్ర', 'మండలం', 'రాష్ట్రములోని విశాఖపట్నం జిల్లాకు'),
#  ('బురుగుపాకలు విశాఖపట్నం', 'గ్రామం', 'జిల్లా మండలానికి'),
#  ('బాలబడి ప్రాథమికోన్నత', 'ఉన్నాయి', 'జెర్రీలలోనూ'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'చింతపల్లిలోను కళాశాల విశాఖపట్నంలోనూ'),
#  ('సమీప వైద్య', 'ఉన్నాయి', 'కళాశాల పాడేరులోనూ'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'అనకాపల్లిలోను'),
#  ('సంచార వైద్య', 'లేరు', 'శాలలో'),
#  ('కాలువ వాగు', 'లభిస్తుంది', 'గ్రామానికి'),
#  ('మురుగునీటిని శుద్ధి', 'పంపిస్తున్నారు', 'ప్లాంట్\u200cలోకి'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('మలయాళ చిత్రం', 'ఆమె', 'సినిమాతో సినీ రంగంలోకి'),
#  ('ఆమె చిత్రం', 'అయింది', 'బెంగుళూర్'),
#  ('ఉస్తాద్ హొటల్', 'ఆమె', 'సినిమాకు'),
#  ('పూణె విశ్వవిద్యాలయంలో', 'ఆమె', 'స్టడీస్ పోస్ట్ గ్రాడ్యుయేషన్'),
#  ('లండన్ ఫిలిం', 'పొందారు', '2003లో స్కూల్ దర్శకత్వ'),
#  ('గ్రాడ్యుయేషన్ రేజ్', 'ప్రదర్శింపబడింది', 'పంజాబీలతో కపాడియా'),
#  ('భారతదేశం ఆసియా', 'అంజలీ', 'కెరీర్'),
#  ('2006లో ముంబైలో', 'మొదలుపెట్టారు', 'మీనన్ ఇండియా కంపెనీ'),
#  ('ఆమె స్క్రీన్', 'రాశారు', 'కథానికలు'),
#  ('మాన్ సూన్', 'ప్రచురితమైంది', 'కథ'),
#  ('ఆమె భర్త', 'అంజలి', 'కొడుకుతో ముంబైలో'),
#  ('సోమవరం తూర్పు', 'గ్రామము', 'మండలానికి'),
#  ('సైన్స్ డిగ్రీ', 'ఉన్నాయి', 'కళాశాల పెద్దాపురంలోనూ'),
#  ('వైద్య కళాశాల', 'ఉన్నాయి', 'కాకినాడలోను కళాశాల పెద్దాపురంలోనూ'),
#  ('వృత్తి విద్యా', 'ఉన్నాయి', 'సామర్లకోట'),
#  ('సంచార వైద్య', 'లేరు', 'శాలలో'),
#  ('డిగ్రీ డాక్టరు', 'ఉన్నారు', 'ఒకరు'),
#  ('గ్రామంలో కుళాయిల', 'జరుగుతోంది', 'సరఫరా'),
#  ('గ్రామంలో ఏడాది', 'అందుతుంది', 'చేతిపంపుల'),
#  ('కాలువ వాగు', 'లభిస్తుంది', 'గ్రామానికి'),
#  ('మురుగునీరు బహిరంగ', 'ప్రవహిస్తుంది', 'కాలువల'),
#  ('గ్రామంలో పారిశుధ్య', 'అమలవుతోంది', 'పథకం'),
#  ('వ్యర్థాలను వ్యవస్థ', 'లేదు', 'ఇంటింటికీ'),
#  ('గంటల వ్యవసాయానికి', 'చేస్తున్నారు', 'కోసం'),
#  ('" సమరం', 'వ్యాసాలు', 'పేరుకు'),
#  ...]

# %%
import os
import re
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from gensim.models import Word2Vec

# Step 3: Creating a Graph
def create_graph(triplets):
    G = nx.Graph()
    for triplet in triplets:
        subject, relation, obj = triplet
        G.add_edge(subject, obj)
    return G

# Main function
def main(data_dir):

    graph = create_graph(triplets)
    df = pd.DataFrame(triplets, columns=['Subject', 'Relation', 'Object'])

    # print(df)

    all_nodes = set(graph.nodes)
    nodes_related_id = [i+1 for i in range(len(all_nodes))]
    node_ids = dict(zip(all_nodes , nodes_related_id))

    relation_list = list(df['Relation'].unique())
    relation_related_ids = [f"r{i+1}" for i in range(len(relation_list))]
    relation_ids = dict(zip(relation_list , relation_related_ids))

    sub_id = []
    for sub in df['Subject']:
      sub_id.append(node_ids[sub])
    df['sub_id'] = sub_id

    rel_id = []
    for rel in df['Relation']:
      rel_id.append(relation_ids[rel])
    df['rel_id'] = rel_id

    obj_id = []
    for obj in df['Object']:
      obj_id.append(node_ids[obj])
    df['obj_id'] = obj_id

    print(df)
    G = nx.DiGraph()

    # Add nodes and edges to the graph
    for index, row in df.iterrows():
      # print(index , row)
        G.add_edge(row['sub_id'], row['obj_id'], label=row['rel_id'])


    # Draw the graph
    fig, ax = plt.subplots(figsize=(12, 8))  # Adjust the size here
    pos = nx.spring_layout(G, seed=42)  # positions for all nodes, using a fixed seed value
    nx.draw_networkx_nodes(G, pos, node_size=300)
    nx.draw_networkx_edges(G, pos)
    nx.draw_networkx_labels(G, pos)

    # Add edge labels
    edge_labels = nx.get_edge_attributes(G, 'label')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

    plt.axis('off')
    plt.show()


data_directory = "/content/drive/MyDrive/Data1"
graph = main(data_directory)
# Out:
#                   Subject         Relation             Object  sub_id rel_id  \
# 0           గుంటూరు జాతీయ             ఆలయం  రహదారికి మైదానంలో    8916     r1
# 1          ప్రపంచంలో మంగళ        కనిపించదు               మనకు   12088     r2
# 2             శ్రీ భూసమేత  పేర్కొంటున్నారు         తలమానికంగా   19890     r3
# 3       ఏడుకొండలపై కొలువై          చేసింది            అమరావతి   13548     r4
# 4           శ్రీ గ‌ణ‌ప‌తి        జ‌రిగింది   ఆశిస్సుల‌తో ఆల‌య   11215     r5
# ...                   ...              ...                ...     ...    ...
# 15373         సంచార వైద్య             లేరు              శాలలో   13504    r73
# 15374    గ్రామంలో కుళాయిల       జరుగుతోంది              సరఫరా   17242    r58
# 15375  గ్రామంలో పారిశుధ్య       అమలవుతోంది               పథకం   14237    r62
# 15376  వ్యర్థాలను వ్యవస్థ             లేదు          ఇంటింటికీ    3496    r63
# 15377   గంటల వ్యవసాయానికి     చేస్తున్నారు               కోసం   18768    r64
#
#        obj_id
# 0        6490
# 1       15239
# 2       15490
# 3        2202
# 4        2919
# ...       ...
# 15373   15980
# 15374   17554
# 15375    8755
# 15376   21739
# 15377    1803
#
# [15378 rows x 6 columns]

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
entities = set()
relations = set()

for head, relation, tail in triplets:
    entities.add(head)
    entities.add(tail)
    relations.add(relation)

entity2idx = {entity: idx for idx, entity in enumerate(entities)}
relation2idx = {relation: idx for idx, relation in enumerate(relations)}

indexed_triplets = [(entity2idx[head], relation2idx[relation], entity2idx[tail]) for head, relation, tail in triplets]

thead = torch.LongTensor([triplet[0] for triplet in indexed_triplets])
trelation = torch.LongTensor([triplet[1] for triplet in indexed_triplets])
ttail = torch.LongTensor([triplet[2] for triplet in indexed_triplets])

# %%
entity2idx.items()
# Out:
# dict_items([('కళలో భిక్షాటన', 0), ('చుట్టూ దీర్ఘ', 1), (',129 616', 2), ('సాహిత్యాన్ని', 3), ('ఆంగ్ల', 4), ('బ్లాంచెట్ Elizabeth', 5), ('క్రీడలకు ప్రాధాన్యత', 6), ('64 ఈశాన', 7), ('ప్రవే', 8), ('బ్ర్రిచెట్టీ', 9), ('బొంబాయి', 10), ('వ్యతిరేకతను', 11), ('ఆమ్ల పొగమంచు', 12), ('అసెంబ్లీలో', 13), ('పరీక్షలకు పరీక్షలో ఆమెకు', 14), ('సాంబమూర్తి', 15), ('జూన్ ఆస్ట్రేలియా స్థిరాస్తి', 16), ('విలాయత్', 17), ('దివ్యమయిన', 18), ('ఊరగాయలు చేపలు', 19), ('ఇంటినుంచి', 20), ('మతసామరస్యానికి', 21), ('బయటి', 22), ('మాఇద్దరినీ', 23), ('ఆక్రమిత ఇథియోపియాను', 24), ('ఆశవాన్ని జంతువులా', 25), ('శతాబ్ది నాటికే', 26), ('న్యూకాజిల్ జట్టులోకి', 27), ('పామాయిల్ అలివ్', 28), ('లోయలో', 29), ('సంగీతకారుడైన త్యాగరాజ', 30), ('ఇవే ఫారోల', 31), ('2016', 32), ('కృష్ణుడు రూపాలు', 33), ('కుటుంబం అంత్యక్రియల', 34), ('అత్యుత్తమ కృష్ణునిగా', 35), ('రాష్ట్రప్రభుత్వ ఆధీనంలో', 36), ('అతడు మంది', 37), ('ఆఫ్రికా ప్రజల్లోని', 38), ('135 )', 39), ('మందిలో బిపికి', 40), ('స్నేహంలో', 41), ('అతనిని కొండవద్దకు', 42), ('సోదరుడు ఆంటన్', 43), ('హౌడులో', 44), ('బాలబడి నవీపేట్లోను', 45), ('మించి', 46), ('విభాగాలలో భాషలలో', 47), ('జనవరి 2008న', 48), ('దైహికం బీజమార్గ', 49), ('ఇంటి కన్నెత్తి', 50), ('రేడియో రామారావు', 51), ('ఫిబ్రవరి నెలలో', 52), ('నారింజ పళ్ల', 53), ('ఆంధ్రప్రదేశ్ నట శిక్షణాలయాన్ని వర్థమాన నటులను', 54), ('సర్కస్\u200cలలో', 55), ('కొల్లాయిడ్స్ తెలుగులొ', 56), ('కలగలుపులతో', 57), ('దీనికి వ్యతిరేకంగా', 58), ('ఆపరేషన్ Cessarian', 59), ('విభాగం నోబెల్', 60), ('ఆరోగ్

#  (14236, 5153, 8754),
#  (3495, 5195, 21738),
#  (11814, 3376, 1047),
#  (943, 4651, 11614),
#  (1367, 3376, 11367),
#  (13671, 3376, 12128),
#  (6161, 616, 21494),
#  (16405, 4077, 1985),
#  (13465, 66, 16932),
#  (7920, 608, 9471),
#  (5617, 1309, 17705),
#  (7881, 3161, 7710),
#  (16703, 4335, 18420),
#  (8191, 3262, 5202),
#  (9338, 3786, 7046),
#  (11452, 3786, 4822),
#  (1320, 3786, 9718),
#  (13503, 2571, 15979),
#  (958, 2542, 17074),
#  (17241, 2214, 17553),
#  (13936, 4016, 4690),
#  (2611, 4465, 19893),
#  (3537, 4223, 20864),
#  (14236, 5153, 8754),
#  (3495, 5195, 21738),
#  (18767, 2719, 1802),
#  (10582, 132, 8161),
#  ...]

# %%
head
# Out:
# 'గంటల వ్యవసాయానికి'

# %%
import random

import random

def generate_negative_triplets(true_triplets, entities):
    negative_triplets = []
    entity_list = list(entities)  # Convert set to list

    if not entity_list:  # Check if the entity_list is empty
        raise ValueError("The entity list is empty.")

    for triplet in true_triplets:
        head, relation, tail = triplet

        negative_head = random.choice(entity_list)
        while negative_head == head:
            negative_head = random.choice(entity_list)

        negative_tail = random.choice(entity_list)
        while negative_tail == tail:
            negative_tail = random.choice(entity_list)

        negative_triplets.append([negative_head, relation, negative_tail])

    return negative_triplets

negative_triplets = generate_negative_triplets(triplets, entities)

neg_entities = set()
for head, relation, tail in negative_triplets:
    neg_entities.add(head)
    neg_entities.add(tail)


neg_indexed_triplets = [(entity2idx[head], relation2idx[relation], entity2idx[tail]) for head, relation, tail in negative_triplets]

neg_head = torch.LongTensor([triplet[0] for triplet in neg_indexed_triplets])
neg_relation = torch.LongTensor([triplet[1] for triplet in neg_indexed_triplets])
neg_tail = torch.LongTensor([triplet[2] for triplet in neg_indexed_triplets])

# %%
head
# Out:
# 'సేనావాహినితో'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

class TransEModel(nn.Module):
    def __init__(self, num_entities, num_relations, embedding_dim, margin):
        super(TransEModel, self).__init__()
        self.entity_embeddings = nn.Embedding(num_entities, embedding_dim)
        self.relation_embeddings = nn.Embedding(num_relations, embedding_dim)
        self.margin = margin
        self.loss_fn = nn.MarginRankingLoss(margin=margin)

        # Initialize embeddings
        nn.init.xavier_uniform_(self.entity_embeddings.weight.data)
        nn.init.xavier_uniform_(self.relation_embeddings.weight.data)

    def forward(self, head, relation, tail, neg_head, neg_tail):
        head_emb = self.entity_embeddings(head)
        relation_emb = self.relation_embeddings(relation)
        tail_emb = self.entity_embeddings(tail)
        neg_head_emb = self.entity_embeddings(neg_head)
        neg_tail_emb = self.entity_embeddings(neg_tail)

        pos_dist = torch.norm(head_emb + relation_emb - tail_emb, p=1, dim=1)
        neg_dist_head = torch.norm(neg_head_emb + relation_emb - tail_emb, p=1, dim=1)
        neg_dist_tail = torch.norm(head_emb + relation_emb - neg_tail_emb, p=1, dim=1)

        return pos_dist, neg_dist_head, neg_dist_tail

    def score_triplets(self, head, relation, tail):
        head_emb = self.entity_embeddings(head)
        relation_emb = self.relation_embeddings(relation)
        tail_emb = self.entity_embeddings(tail)
        dist = torch.norm(head_emb + relation_emb - tail_emb, p=1, dim=1)
        return dist

    def loss(self, pos_dist, neg_dist_head, neg_dist_tail):
        target = torch.ones(pos_dist.size())
        return self.loss_fn(pos_dist, neg_dist_head, target) + self.loss_fn(pos_dist, neg_dist_tail, target)

# Hyperparameters
num_entities = len(entity2idx)
num_relations = len(relation2idx)
embedding_dim = 64
margin = 1.0
learning_rate = 0.001
num_epochs = 100

# Create the model
model = TransEModel(num_entities, num_relations, embedding_dim, margin)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training loop
for epoch in range(num_epochs):
    pos_dist, neg_dist_head, neg_dist_tail = model(thead, trelation, ttail, neg_head, neg_tail)
    loss = model.loss(pos_dist, neg_dist_head, neg_dist_tail)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")



entity_embeddings = model.entity_embeddings.weight.data.cpu().numpy()
relation_embeddings = model.relation_embeddings.weight.data.cpu().numpy()

# Create embedding dictionaries
true_embeddings_dict = {idx : entity_embeddings[idx] for entity, idx in entity2idx.items()}
true_embeddings_dict.update({idx : relation_embeddings[idx] for relation, idx in relation2idx.items()})

neg_embeddings_dict = true_embeddings_dict.copy()
# Out:
# Epoch 0, Loss: 1.9944345951080322
# Epoch 10, Loss: 0.5456264019012451
# Epoch 20, Loss: 0.028631020337343216
# Epoch 30, Loss: 0.0006615701131522655
# Epoch 40, Loss: 5.4214062402024865e-05
# Epoch 50, Loss: 1.5633781003998592e-05
# Epoch 60, Loss: 6.404324722097954e-06
# Epoch 70, Loss: 0.0
# Epoch 80, Loss: 0.0
# Epoch 90, Loss: 0.0

# %%
true_embeddings_dict
# Out:
# {0: array([-0.02295585, -0.00746829,  0.01789725,  0.03265849,  0.00551661,
#          0.02776701,  0.00275015,  0.00351793, -0.00695976, -0.01280614,
#         -0.01243846, -0.02650256,  0.02980072, -0.01053678,  0.02076592,
#          0.0326416 , -0.01717565, -0.01869662, -0.01525156, -0.02587121,
#         -0.03251555, -0.00406633, -0.0304997 , -0.02106341, -0.02330081,
#          0.02987399,  0.03019608, -0.01770972,  0.00271586, -0.000833  ,
#          0.03066314, -0.03241945,  0.02460285,  0.00456842,  0.00320924,
#          0.00105051, -0.02229529,  0.01476138,  0.03246646,  0.01788675,
#          0.00329369, -0.02950162,  0.02588097,  0.01738583, -0.02053604,
#         -0.02229131, -0.0139499 ,  0.03156507,  0.01980383,  0.01286917,
#          0.0256222 ,  0.02656024, -0.02177343, -0.00303516, -0.03242347,
#         -0.02418158,  0.01497843, -0.02845128, -0.02863172, -0.00116271,
#         -0.00172114,  0.01530155,  0.01435822, -0.01061321], dtype=float32),
#  1: array([-0.02409412, -0.02127329, -0.02873496,  0.01777776, -0.01282582,
#         -0.03633122,  0.03184232, -0.02959929, -0.00105746, -0.01309903,
#         -0.01880864,  0.00629007,  0.02785279,  0.04051549, -0.00348468,
#         -0.00585203, -0.02184003, -0.03815661, -0.03037257,  0.0183516 ,
#         -0.05171229,  0.03356705, -0.01323474,  0.01931128,  0.00979461,
#         -0.03789242,  0.04045051, -0.01505348, -0.02163143, -0.01257894,
#         -0.01915184,  0.03182795, -0.02031919,  0.01504643, -0.007783  ,
#          0.02127198,  0.0038269 , -0.00052403, -0.01329303,  0.00468108,
#         -0.00210341, -0.00021947,  0.01426812,  0.02342645, -0.00617074,
#         -2.2980187e-02, -1.6044008e-02, -2.6897941e-02,  2.9170871e-02,
#         -1.5339127e-02, -2.3448516e-02, -3.1378012e-02,  7.7571094e-05,
#         -1.0692988e-02, -3.2900292e-02,  1.5042428e-02,  3.1645928e-02,
#          3.2961819e-02,  2.5267862e-02,  2.1381740e-02,  1.2318909e-02,
#          2.1285880e-02, -2.3297995e-02, -3.0802518e-02, -3.0019486e-02,
#         -8.0838939e-03, -1.1929678e-02, -2.6176447e-02, -1.7974813e-02,
#          2.4500079e-02, -2.5456503e-02, -7.9161823e-03,  1.1431988e-02,
#         -2.5623010e-02,  3.0411858e-02, -1.8625148e-02,  2.9035926e-02,
#          3.0402999e-02, -2.8082088e-02,  2.9111020e-03,  2.5117394e-02],
#        dtype=float32),
#  999: array([ 0.01202084, -0.02610878, -0.02967113,  0.00581714,  0.00397194,
#         -0.02869786,  0.00994204, -0.00470984,  0.00829905, -0.02424873,
#          0.01322893,  0.01630006, -0.02466621,  0.00223307,  0.01560359,
#         -0.01077128,  0.00102679, -0.03172496, -0.00501813,  0.028526  ,
#         -0.02810624,  0.00102194, -0.02661056, -0.02161605,  0.03054042,
#          0.0136811 ,  0.03101687, -0.0302128 , -0.02011239,  0.01990145,
#          0.02525821,  0.01809784, -0.01715703,  0.0249936 , -0.02308417,
#         -0.00113782,  0.01761614,  0.02987636, -0.02215367, -0.02659255,
#          0.01186151, -0.02764809,  0.00752009,  0.0177164 , -0.00495444,
#         -0.00224454,  0.01153634, -0.02463808,  0.00684382,  0.00304968,
#         -0.01758282, -0.0199686 ,  0.01921476, -0.03242826, -0.00951246,
#          0.02493292, -0.02426055,  0.01058414, -0.01517724, -0.00882309,
#         -0.02524515, -0.01755909,  0.00491827,  0.00857091], dtype=float32),
#  ...}

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def calculate_cosine_similarities(triples, embeddings_dict):
    similarities = []
    for head, relation, obj in triples:
        if head in embeddings_dict and relation in embeddings_dict and obj in embeddings_dict:
            head_embedding = embeddings_dict[head]
            relation_embedding = embeddings_dict[relation]
            obj_embedding = embeddings_dict[obj]

            # Calculate cosine similarities
            head_obj_similarity = cosine_similarity([head_embedding], [obj_embedding])[0][0]
            head_relation_similarity = cosine_similarity([head_embedding], [relation_embedding])[0][0]
            relation_obj_similarity = cosine_similarity([relation_embedding], [obj_embedding])[0][0]

            # Average cosine similarity
            average_similarity = (head_obj_similarity + head_relation_similarity + relation_obj_similarity) / 3

            similarities.append((head, relation, obj, average_similarity))
        else:
            similarities.append((head, relation, obj, None))  # In case of missing embeddings
    return similarities

def compare_triplets(true_triplets, negative_triplets, true_embeddings_dict, negative_embeddings_dict, threshold):
    true_similarities = calculate_cosine_similarities(true_triplets, true_embeddings_dict)
    negative_similarities = calculate_cosine_similarities(negative_triplets, negative_embeddings_dict)

    valid_negative_triplets = []

    for true_triplet, neg_triplet in zip(true_similarities, negative_similarities):
        true_head, true_relation, true_obj, true_similarity = true_triplet
        neg_head, neg_relation, neg_obj, neg_similarity = neg_triplet

        if true_similarity is not None and neg_similarity is not None and true_similarity > neg_similarity + threshold:
            valid_negative_triplets.append(neg_triplet[:3])

    return valid_negative_triplets

# Example usage to identify hidden triplets from negative samples
hidden_rels = compare_triplets(indexed_triplets, neg_indexed_triplets, true_embeddings_dict, neg_embeddings_dict, threshold = 0.01)
hidden_relations = list(set(hidden_rels))

valid_neg_tuples = []
entity_keys = list(entity2idx.keys())
entity_values = list(entity2idx.values())
relation_keys = list(relation2idx.keys())
relation_values = list(relation2idx.values())

for triplet in hidden_relations:
    head_entity = entity_keys[entity_values.index(triplet[0])]
    relation = relation_keys[relation_values.index(triplet[1])]
    tail_entity = entity_keys[entity_values.index(triplet[2])]
    valid_neg_tuples.append((head_entity, relation, tail_entity))

# Print valid_neg_tuples to verify the result
print(valid_neg_tuples)
# Out:
# [('దాసరి రామానాయుడు', 'వుండును', 'ఐకమత్యంతో'), ('him', 'పంపెను', 'గాజుతో'), ('వీధిలోని ముందుభాగంలో', 'ఉన్నారు', 'వర్ణనలో ఘట్టాలలో అతీతుడనీ'), ('రామారావుల వివాదాలు', 'అందుతుంది', 'మద్రాసు ప్రెసిడెన్సీలో'), ('ICSE', 'మరణించాడు', 'బాలసుబ్రహ్మణ్యం తెలుగు'), ('జాతీయ మార్పిడి', 'వశమైంది', 'ఉమ్మడి ఆంధ్రప్రదేశ్'), ('అబ్బాయిలేమోకర్ర బిళ్ళ', 'చల్లార్చేదరు', 'ఫైనల్ అక్టోబరులో'), ('ముంబాయిలో', 'దక్కించుకున్నారు', 'వైపుల'), ('కడలిని ఆవలి', 'అవసరమవుతుంది', 'ఫెర్మా ఉద్యోగాన్ని'), ('ఖల్డా అల్', 'అనుసరించారు', '18మందిని'), ('సంస్థలో ప్రణాళిక', 'అప్పగించారు', 'దృపదుడు అవమానాన్ని'), ('ఒకరినొకరు వేటకు జంటలోని', 'వెనుదిరిగాడు', 'ఎక్జామినేషన్స్'), ('భారతదేశంలో ప్రాంతములలో', 'అవతరించినవాడు', 'దుకాణాలలో'), ('జూన్ 26 సమావేశంలో ఛార్టర్\u200cపై', 'కనిపిస్తుంది', 'వాహనంలో ఆస్థానానికి'), ('జైపూర్ రాజులు', 'పోషించింది', 'కావ్యదర్పణంన'), ('మనిషి', 'విఫలమయ్యిందని', 'లెజిస్లేటివ్ అసెంబ్లీలో'), ('గాఢాలింగనము నీకు', 'ఆయనే', 'జాతి ఆధిపత్య'), ('మద్రాసు హైదరాబాదు\u200cకు', 'పార్కర్', 'చేతుల దూరం'), ('సందేహాలను', 'విలీనంచేయబడాయి', 'కర్రతో శక్తిని'), ('అధికారులు అధికారాన్ని', 'ఉన్నాయి', 'డబ్బు'), ('తాను హిందూ', 'పరుగెత్తేవారు', 'నేటి ప్రజలతో'), ('ఇంటికి గర్భంలో', 'అన్నాడు', 'జనాభా'), ('కాంగ్రెస్ అతనినే', 'వ్రాలాడు', 'పడమరలో'), ('ఉపరితలముపైన', 'చెందినది', 'ప్రజాఉద్యమ దళాలకు'), ('2007లో ఆతిథ్యం', 'అందుతుంది', 'పాత్రకుగాను'), ('కార్పోరేటర్\u200cగా',
్రిగారు ఇందిరా'), ('గ్రామాలుతో', 'వంటివి', 'వాసు దర్శకత్వంలో'), ('పారిస్ లోని', 'ధరించినవాడు', 'పగ్గాలు'), ('క్రితమే పోఖ్రాన్ అణు సైనికపాలనలోకి విధానంలో', 'చేయిస్తాను', 'బారా కోటిస్'), ('తప్పు పప్పులో', 'పోతుంది', 'ప్రతిపక్ష నాయకులు'), ('పాఠశాలలో', 'కాలేదు', 'ప్రస్తుత US'), ('నారాయణుని అతని', 'భాగమైపోయింది', 'అంతర్గత పోరాటాల'), ('పరీక్షలో అతనికి', 'ఉన్నాయి', 'పువ్వుల పళ్లెరాన్ని'), ('ప్రతివారిని', 'చేస్తున్నారు', 'నగర'), ('వ్యోమనాట్లకు శిక్షణ', 'ఉండేది', 'విధమైన హక్కు'), ('అగ్నిదేవుడిని వద్దకు', 'ఎన్నుకోబడ్డాడు', 'ప్రదర్శనలు రాబ్సన్'), ('హేమాండ్ పంతు', 'విడుదలైంది', 'నగరానికి'), ('పాకిస్తానీ దినపత్రిక', 'పంపిస్తున్నారు', 'చిన్నపిల్లల్లో గుండె'), ('సాహిత్యంలో', 'చేస్తున్నారు', 'సమాధిలో'), ('సంవత్సరం ఫాల్గుణ', 'గర్వకారణం', 'ధర్మరాజు శ్రీకృష్ణునితో'), ('త్వరలో', 'ఒప్పుకోలేకపోయారు', 'హర్యానా రాష్ట్రాన్ని'), ('విశ్వవిద్యాలయం', 'ఘట్టం', 'కవాటంలో అవకాశం'), ('000కు', 'అందుతుంది', 'గడ ...

# %%
len(valid_neg_tuples)
# Out:
# 4579

# %%
def score_triple(triple, embeddings):
    head, relation, tail = triple
    head_emb = embeddings[head]
    relation_emb = embeddings[relation]
    tail_emb = embeddings[tail]

    score = np.linalg.norm(head_emb + relation_emb - tail_emb)
    return -score

# %%
def hits_at_k(true_triples, false_triples, embeddings, ks):
    true_ranks = []
    true_scores = [score_triple(triple, embeddings) for triple in true_triples]
    false_scores = [score_triple(triple, embeddings) for triple in false_triples]

    hits_at_ks = {k: 0 for k in ks}
    for true_score in true_scores:
        rank = sum(1 for false_score in false_scores if false_score < true_score) + 1
        true_ranks.append(rank)
        for k in ks:
            if rank <= k:
                hits_at_ks[k] += 1

    mean_rank = np.mean(true_ranks)
    mrr = np.mean([1.0 / rank for rank in true_ranks])
    hits_at_k_scores = {k: hits / len(true_triples) for k, hits in hits_at_ks.items()}
    
    return hits_at_k_scores, mean_rank, mrr



hits_at_k_scores, mean_rank, mrr = hits_at_k(indexed_triplets,neg_indexed_triplets, true_embeddings_dict, [1, 5, 10])
print(f"Hits@1: {hits_at_k_scores[1]}")
print(f"Hits@5: {hits_at_k_scores[5]}")
print(f"Hits@10: {hits_at_k_scores[10]}")
print(f"Mean Rank: {mean_rank}")
print(f"Mean Reciprocal Rank (MRR): {mrr}")
# Out:
# Hits@1: 0.6051502145922747
# Hits@5: 0.6431915723761217
# Hits@10: 0.6656262192742879
# Mean Rank: 276.06366237482115
# Mean Reciprocal Rank (MRR): 0.6261454835521285
